# %% [markdown]
# # Wordnet and Named entity recognition (NER)
#
# - NLTK
# - Spacy
# - Stanza

# %%
import nltk

#from nltk.tokenize import word_tokenize
#from nltk.tokenize import sent_tokenize
#from nltk.tag import pos_tag
#from nltk import conlltags2tree, tree2conlltags

from nltk.corpus import wordnet as wn

# Download the required NLTK resources
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')  # Correct NER chunker model
nltk.download('words') 
nltk.download('maxent_ne_chunker_tab') 


from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tag import pos_tag
from nltk import conlltags2tree, tree2conlltags
from nltk.corpus import wordnet as wn
from nltk.chunk import ne_chunk
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /users/kent/asingh68/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /users/kent/asingh68/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /users/kent/asingh68/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /users/kent/asingh68/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /users/kent/asingh68/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /users/kent/asingh68/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!

# %% [markdown]
# # Wordnet

# %%
# get synset for 'table'

wn.synsets('table')
# Out:
# [Synset('table.n.01'),
#  Synset('table.n.02'),
#  Synset('table.n.03'),
#  Synset('mesa.n.01'),
#  Synset('table.n.05'),
#  Synset('board.n.04'),
#  Synset('postpone.v.01'),
#  Synset('table.v.02')]

# %%
wn.langs()
# Out:
# ['eng']

# %%
wn.synset('table.n.01').definition()
# Out:
# 'a set of data arranged in rows and columns'

# %%
wn.synset('table.n.01').hypernyms()
# Out:
# [Synset('array.n.01')]

# %%
wn.synset('table.n.02').hyponyms()
# Out:
# [Synset('kitchen_table.n.01'),
#  Synset('operating_table.n.01'),
#  Synset('parsons_table.n.01'),
#  Synset('trestle_table.n.01'),
#  Synset('altar.n.01'),
#  Synset('card_table.n.01'),
#  Synset('booth.n.01'),
#  Synset('coffee_table.n.01'),
#  Synset('gaming_table.n.01'),
#  Synset('table-tennis_table.n.01'),
#  Synset('breakfast_table.n.01'),
#  Synset('worktable.n.01'),
#  Synset('platen.n.01'),
#  Synset('dressing_table.n.01'),
#  Synset('drop-leaf_table.n.01'),
#  Synset('conference_table.n.01'),
#  Synset('console_table.n.01'),
#  Synset('pedestal_table.n.01'),
#  Synset('counter.n.01'),
#  Synset('gueridon.n.01'),
#  Synset('desk.n.01'),
#  Synset('pier_table.n.01'),
#  Synset('pool_table.n.01'),
#  Synset('tea_table.n.01'),
#  Synset('card_table.n.02'),
#  Synset('stand.n.04')]

# %%
wn.synset('table.n.02').hypernyms()[0].hypernyms()[0].hypernyms()[0].definition()
# Out:
# 'an artifact (or system of artifacts) that is instrumental in accomplishing some end'

# %%
#w1 = wordnet.synset('ship.n.01')
#w2 = wordnet.synset('boat.n.01')
#print(w1.wup_similarity(w2))


#w1 = wordnet.synset('ship.n.01')
#w2 = wordnet.synset('car.n.01')
#print(w1.wup_similarity(w2))

# Wu-Palmer similarity comparisons
w1 = wn.synset('ship.n.01')
w2 = wn.synset('boat.n.01')
print(w1.wup_similarity(w2))

w1 = wn.synset('ship.n.01')
w2 = wn.synset('car.n.01')
print(w1.wup_similarity(w2))
# Out:
# 0.9090909090909091
# 0.6956521739130435

# %%
synonyms = []

for syn in wn.synsets("cat"):
    for l in syn.lemmas():
        synonyms.append(l.name())

print(set(synonyms))
# Out:
# {'CT', 'barf', 'African_tea', 'regorge', 'computerized_tomography', "cat-o'-nine-tails", 'CAT', 'regurgitate', 'throw_up', 'spue', 'bozo', 'qat', 'computerized_axial_tomography', 'chuck', 'cast', 'vomit', 'true_cat', 'computed_tomography', 'guy', 'cat', 'spew', 'honk', 'purge', 'sick', 'hombre', 'be_sick', 'computed_axial_tomography', 'disgorge', 'retch', 'upchuck', 'kat', 'khat', 'puke', 'Arabian_tea', 'big_cat', 'quat', 'vomit_up', 'Caterpillar'}

# %%
wn.synset('dog.n.01').lemmas()[1].name()
# Out:
# 'domestic_dog'

# %%
print(wn.synset('dog.n.01').examples())
# Out:
# ['the dog barked all night']

# %% [markdown]
# # Named Entity Recognition (NER)
# - NLTK
# - Spacy
# - Stanza

# %%
# convert string into set of POS-tagged sentences
def preprocessText(text, flag = 1):
    # Segment text into sentences
    sent = sent_tokenize(text)
    # Tokenize each sentences
    sent = [nltk.word_tokenize(s) for s in sent]
    # Part-of-speech tagging each sentences
    if(flag == 1) : sent = [nltk.pos_tag(s) for s in sent]
    # list of sentences
    if(flag == 2) : sent = [" ".join(s) for s in sent]
    return sent

# %%
Michelle = """Hi! I'm Michelle and I'm 22.
I really,really like this guy. He's 27 and everything  I like in a guy. We have so much in common.
We met around three and a half months ago. A week after we met, he texted me and we didn't stop talking for a whole month and a half. We talked day and night, sometimes 'til four in the morning.
Then, he started ignoring me. When that started to  happen, a red flag went up in my head, so I started ignoring him, too. Except I started missing him.
Before I started a new semester, I asked him what was the point of saving my number if he wasn't going to ask me out. (Yes, we haven't gone out on a date yet. We've talked about it, but he doesn't make it happen.)
I told him I wasn't going to have enough time for him, and if he really wanted to go out with me, he should make it happen soon rather than later.
I just don't understand why he hasn't asked me out yet. He gives me the money excuse, or the "every time I want to, something else comes up" excuse.
If he wants to see me he should've done so already... right?"""

# %%
# generate POS-tagged list of sentences

MichelleSentenceTagged = preprocessText(Michelle)
for s in MichelleSentenceTagged:
    print(s)
# Out:
# [('Hi', 'NN'), ('!', '.')]
# [('I', 'PRP'), ("'m", 'VBP'), ('Michelle', 'NNP'), ('and', 'CC'), ('I', 'PRP'), ("'m", 'VBP'), ('22', 'CD'), ('.', '.')]
# [('I', 'PRP'), ('really', 'RB'), (',', ','), ('really', 'RB'), ('like', 'IN'), ('this', 'DT'), ('guy', 'NN'), ('.', '.')]
# [('He', 'PRP'), ("'s", 'VBZ'), ('27', 'CD'), ('and', 'CC'), ('everything', 'NN'), ('I', 'PRP'), ('like', 'VBP'), ('in', 'IN'), ('a', 'DT'), ('guy', 'NN'), ('.', '.')]
# [('We', 'PRP'), ('have', 'VBP'), ('so', 'RB'), ('much', 'JJ'), ('in', 'IN'), ('common', 'JJ'), ('.', '.')]
# [('We', 'PRP'), ('met', 'VBD'), ('around', 'IN'), ('three', 'CD'), ('and', 'CC'), ('a', 'DT'), ('half', 'JJ'), ('months', 'NNS'), ('ago', 'RB'), ('.', '.')]
# [('A', 'DT'), ('week', 'NN'), ('after', 'IN'), ('we', 'PRP'), ('met', 'VBD'), (',', ','), ('he', 'PRP'), ('texted', 'VBD'), ('me', 'PRP'), ('and', 'CC'), ('we', 'PRP'), ('did', 'VBD'), ("n't", 'RB'), ('stop', 'VB'), ('talking', 'VBG'), ('for', 'IN'), ('a', 'DT'), ('whole', 'JJ'), ('month', 'NN'), ('and', 'CC'), ('a', 'DT'), ('half', 'NN'), ('.', '.')]
# [('We', 'PRP'), ('talked', 'VBD'), ('day', 'NN'), ('and', 'CC'), ('night', 'NN'), (',', ','), ('sometimes', 'RB'), ("'til", 'CD'), ('four', 'CD'), ('in', 'IN'), ('the', 'DT'), ('morning', 'NN'), ('.', '.')]
# [('Then', 'RB'), (',', ','), ('he', 'PRP'), ('started', 'VBD'), ('ignoring', 'VBG'), ('me', 'PRP'), ('.', '.')]
# [('When', 'WRB'), ('that', 'WDT'), ('started', 'VBD'), ('to', 'TO'), ('happen', 'VB'), (',', ','), ('a', 'DT'), ('red', 'JJ'), ('flag', 'NN'), ('went', 'VBD'), ('up', 'RB'), ('in', 'IN'), ('my', 'PRP$'), ('head', 'NN'), (',', ','), ('so', 'IN'), ('I', 'PRP'), ('started', 'VBD'), ('ignoring', 'VBG'), ('him', 'PRP'), (',', ','), ('too', 'RB'), ('.', '.')]
# [('Except', 'IN'), ('I', 'PRP'), ('started', 'VBD'), ('missing', 'VBG'), ('him', 'PRP'), ('.', '.')]
# [('Before', 'IN'), ('I', 'PRP'), ('started', 'VBD'), ('a', 'DT'), ('new', 'JJ'), ('semester', 'NN'), (',', ','), ('I', 'PRP'), ('asked', 'VBD'), ('him', 'PRP'), ('what', 'WP'), ('was', 'VBD'), ('the', 'DT'), ('point', 'NN'), ('of', 'IN'), ('saving', 'VBG'), ('my', 'PRP$'), ('number', 'NN'), ('if', 'IN'), ('he', 'PRP'), ('was', 'VBD'), ("n't", 'RB'), ('going', 'VBG'), ('to', 'TO'), ('ask', 'VB'), ('me', 'PRP'), ('out', 'RP'), ('.', '.')]
# [('(', '('), ('Yes', 'UH'), (',', ','), ('we', 'PRP'), ('have', 'VBP'), ("n't", 'RB'), ('gone', 'VBN'), ('out', 'RP'), ('on', 'IN'), ('a', 'DT'), ('date', 'NN'), ('yet', 'RB'), ('.', '.')]
# [('We', 'PRP'), ("'ve", 'VBP'), ('talked', 'VBN'), ('about', 'IN'), ('it', 'PRP'), (',', ','), ('but', 'CC'), ('he', 'PRP'), ('does', 'VBZ'), ("n't", 'RB'), ('make', 'VB'), ('it', 'PRP'), ('happen', 'VB'), ('.', '.'), (')', ')')]
# [('I', 'PRP'), ('told', 'VBD'), ('him', 'PRP'), ('I', 'PRP'), ('was', 'VBD'), ("n't", 'RB'), ('going', 'VBG'), ('to', 'TO'), ('have', 'VB'), ('enough', 'JJ'), ('time', 'NN'), ('for', 'IN'), ('him', 'PRP'), (',', ','), ('and', 'CC'), ('if', 'IN'), ('he', 'PRP'), ('really', 'RB'), ('wanted', 'VBD'), ('to', 'TO'), ('go', 'VB'), ('out', 'RP'), ('with', 'IN'), ('me', 'PRP'), (',', ','), ('he', 'PRP'), ('should', 'MD'), ('make', 'VB'), ('it', 'PRP'), ('happen', 'VB'), ('soon', 'RB'), ('rather', 'RB'), ('than', 'IN'), ('later', 'RB'), ('.', '.')]
# [('I', 'PRP'), ('just', 'RB'), ('do', 'VBP'), ("n't", 'RB'), ('understand', 'VB'), ('why', 'WRB'), ('he', 'PRP'), ('has', 'VBZ'), ("n't", 'RB'), ('asked', 'VBN'), ('me', 'PRP'), ('out', 'RP'), ('yet', 'RB'), ('.', '.')]
# [('He', 'PRP'), ('gives', 'VBZ'), ('me', 'PRP'), ('the', 'DT'), ('money', 'NN'), ('excuse', 'NN'), (',', ','), ('or', 'CC'), ('the', 'DT'), ('``', '``'), ('every', 'DT'), ('time', 'NN'), ('I', 'PRP'), ('want', 'VBP'), ('to', 'TO'), (',', ','), ('something', 'NN'), ('else', 'RB'), ('comes', 'VBZ'), ('up', 'RP'), ("''", "''"), ('excuse', 'NN'), ('.', '.')]
# [('If', 'IN'), ('he', 'PRP'), ('wants', 'VBZ'), ('to', 'TO'), ('see', 'VB'), ('me', 'PRP'), ('he', 'PRP'), ('should', 'MD'), ("'ve", 'VBP'), ('done', 'VBN'), ('so', 'RB'), ('already', 'RB'), ('...', ':'), ('right', 'RB'), ('?', '.')]

# %% [markdown]
# # NLTK  Named Entity Recognition
# https://www.nltk.org/book_1ed/ch07.html

# %%
# NER ne_chunk
#MichelleChunked = [nltk.ne_chunk(sent) for sent in MichelleSentenceTagged]
#MichelleChunked[:2]


# Process text
michelle_sentences_tagged = preprocessText(Michelle)

# Named Entity Recognition (NER)
michelle_chunked = [ne_chunk(sent) for sent in michelle_sentences_tagged]

# Print first two NER chunks
for tree in michelle_chunked[:2]:
    print(tree)
# Out:
# (S (GPE Hi/NN) !/.)
# (S I/PRP 'm/VBP (PERSON Michelle/NNP) and/CC I/PRP 'm/VBP 22/CD ./.)

# %%
michelle_chunked = [ne_chunk(sent) for sent in michelle_sentences_tagged]

# %%
#michelle_sentences_tagged 
#ne_chunk(michelle_sentences_tagged[1])
# Display first two NER chunks
from nltk.tree import Tree
for i, tree in enumerate(michelle_chunked[:2], start=1):
    print(f"\nNamed Entities in Sentence {i}:")
    for subtree in tree:
        if isinstance(subtree, Tree):  # Named Entity chunk
            print("  ", subtree)
# Out:
# Named Entities in Sentence 1:
#    (GPE Hi/NN)
#
# Named Entities in Sentence 2:
#    (PERSON Michelle/NNP)

# %%
#for tree in michelle_chunked:
    #print(tree)

# %%
#for tree in michelle_chunked:
    #for chunk in tree:
        #if hasattr(chunk, "label"):
            #print(chunk.label(), str(chunk)) 
        #else : print("\t", chunk)
    #print("--------")

# %% [markdown]
# ### NLTL IOB tags
# - B: begin
# - I: inside
# - O: outside

# %%
# first Michelle sentence
tree = michelle_chunked[1]
print("Tree:", tree)

# Convert Assign IOB tags
iob_tags = tree2conlltags(tree)
print("\nIOB:", iob_tags)

# Reverse operation: IOB to chunks tags
conll = conlltags2tree(iob_tags)
print("Tree:", conll)
# Out:
# Tree: (S I/PRP 'm/VBP (PERSON Michelle/NNP) and/CC I/PRP 'm/VBP 22/CD ./.)
#
# IOB: [('I', 'PRP', 'O'), ("'m", 'VBP', 'O'), ('Michelle', 'NNP', 'B-PERSON'), ('and', 'CC', 'O'), ('I', 'PRP', 'O'), ("'m", 'VBP', 'O'), ('22', 'CD', 'O'), ('.', '.', 'O')]
# Tree: (S I/PRP 'm/VBP (PERSON Michelle/NNP) and/CC I/PRP 'm/VBP 22/CD ./.)

# %% [markdown]
# ## Load Books

# %%
# import books brom NLTK (text1 ... text9)
import re
import nltk
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# make a text string from nltk.book.text1
text = ' '.join(nltk.book.text1)

# sentence segmentation, tokenization tagging 
text1Sents = preprocessText(text)

for s in [0,1]:
    print(text1Sents[s], "\n")
# Out:
# [('[', 'JJ'), ('Moby', 'NNP'), ('Dick', 'NNP'), ('by', 'IN'), ('Herman', 'NNP'), ('Melville', 'NNP'), ('1851', 'CD'), (']', 'NNP'), ('ETYMOLOGY', 'NNP'), ('.', '.')]
#
# [('(', '('), ('Supplied', 'VBN'), ('by', 'IN'), ('a', 'DT'), ('Late', 'JJ'), ('Consumptive', 'NNP'), ('Usher', 'NNP'), ('to', 'TO'), ('a', 'DT'), ('Grammar', 'NNP'), ('School', 'NNP'), (')', ')'), ('The', 'DT'), ('pale', 'NN'), ('Usher', 'NNP'), ('--', ':'), ('threadbare', 'NN'), ('in', 'IN'), ('coat', 'NN'), (',', ','), ('heart', 'NN'), (',', ','), ('body', 'NN'), (',', ','), ('and', 'CC'), ('brain', 'NN'), (';', ':'), ('I', 'PRP'), ('see', 'VBP'), ('him', 'PRP'), ('now', 'RB'), ('.', '.')]

# %%
# Create the named entity chunks: chunked_sentences
#text1Chunked = [nltk.ne_chunk(s) for s in text1Sents]
#print("chunked")

# dictionary to store NEs
#NE_NLTK_text1 = {}

# extract NEs tags
#for sent in text1Chunked:
    #for chunk in sent:
        #if hasattr(chunk, "label"):
            #z = str(chunk) # to make the chunk idexable
            #NE_NLTK_text1.setdefault(z, 0)
            #NE_NLTK_text1[z] += 1
# Create the named entity chunks
text1Chunked = [ne_chunk(sent) for sent in text1Sents]
print("Chunked Sentences Processed")

# Dictionary to store named entities
NE_NLTK_text1 = {}

# Extract named entity tags
for sent in text1Chunked:
    for chunk in sent:
        if isinstance(chunk, nltk.Tree):  # Ensure it's a chunked entity
            entity = " ".join(c[0] for c in chunk)  # Extract entity words
            label = chunk.label()  # Get entity type
            entity_label = f"{entity} ({label})"  # Format entity with label
            NE_NLTK_text1[entity_label] = NE_NLTK_text1.get(entity_label, 0) + 1

# Print extracted named entities
print("Extracted Named Entities:")
print(NE_NLTK_text1)
# Out:
# Chunked Sentences Processed
# Extracted Named Entities:
# {'Herman Melville (PERSON)': 1, 'Late Consumptive (ORGANIZATION)': 1, 'Grammar School (ORGANIZATION)': 1, 'HACKLUYT (ORGANIZATION)': 1, 'Dan (PERSON)': 1, 'Dan (GPE)': 1, 'HVALT (GPE)': 2, 'Dut (ORGANIZATION)': 1, 'Ger (GPE)': 1, 'WALLEN (GPE)': 1, 'WALW (ORGANIZATION)': 1, 'IAN (GPE)': 1, 'RICHARDSON (ORGANIZATION)': 1, 'GREEK (GPE)': 1, 'CETUS (GPE)': 1, 'LATIN (ORGANIZATION)': 1, 'WHOEL (GPE)': 1, 'ANGLO (ORGANIZATION)': 1, 'SAXON (ORGANIZATION)': 1, 'DANISH (GPE)': 2, 'DUTCH (GPE)': 2, 'HWAL (GPE)': 1, 'SWEDISH (GPE)': 1, 'WHALE (GPE)': 2, 'ICELANDIC (ORGANIZATION)': 1, 'ENGLISH (GPE)': 3, 'BALEINE (GPE)': 1, 'FRENCH (GPE)': 4, 'BALLENA (GPE)': 1, 'SPANISH (GPE)': 4, 'PEKEE (GPE)': 2, 'NUEE (ORGANIZATION)': 4, 'FEGEE (ORGANIZATION)': 1, 'ERROMANGOAN (ORGANIZATION)': 1, 'EXTRACTS (GPE)': 2, 'Sub (ORGANIZATION)': 3, 'Sub (GPE)': 1, 'Librarian (GPE)': 1, 'Sub (PERSON)': 3, 'Leviathan (GPE)': 6, 'Pale Sherry (PERSON)': 1, 'Subs (PERSON)': 1, 'Hampton Court (ORGANIZATION)': 1, 'Tuileries (ORGANIZATION)': 3, 'Gabriel (PERSON)': 19, 'Michael (PERSON)': 1, 'Raphael (GPE)': 1, 'God (PERSON)': 36, 'Lord (ORGANIZATION)': 14, 'Jonah (PERSON)': 62, 'Leviathan (PERSON)': 23, 'HOLLAND (ORGANIZATION)': 2, 'Indian (GPE)': 55, 'Sea (ORGANIZATION)': 3, 'Whales (ORGANIZATION)': 1, 'Whirlpooles (PERSON)': 1, 'Balaene (PERSON)': 1, 'TOOKE (ORGANIZATION)': 1, 'TRUE (ORGANIZATION)': 1, 'D (GPE)': 12, 'APOLOGY FOR (ORGANIZATION)': 1, 'RAIMOND (ORGANIZATION)': 1, 'Old (PERSON)': 2, 'Nick (PERSON)': 1, 'RABELAIS (ORGANIZATION)': 1, 'LORD (ORGANIZATION)': 1, 'THE (ORGANIZATION)': 40, 'PSALMS (ORGANIZATION)': 1, 'HISTORY (ORGANIZATION)': 1, 'OF (ORGANIZATION)': 3, 'HENRY (ORGANIZATION)': 2, 'HAMLET (ORGANIZATION)': 1, 'FAERIE (ORGANIZATION)': 1, 'Immense (GPE)': 1, 'SIR (ORGANIZATION)': 2, 'Nescio (GPE)': 1, 'SIR T (ORGANIZATION)': 2, 'BROWNE (GPE)': 2, 'SPERMA (ORGANIZATION)': 2, 'VIDE (ORGANIZATION)': 1, 'Spencer (PERSON)': 1, 'WALLER (ORGANIZATION)': 1, 'SUMMER (ORGANIZATION)': 1, 'Latin (GPE)': 3, 'Civitas (GPE)': 1, 'SENTENCE OF (ORGANIZATION)': 1, 'HOBBES (ORGANIZATION)': 1, 'Mansoul (PERSON)': 1, 'PILGRIM (ORGANIZATION)': 1, 'PARADISE (ORGANIZATION)': 1, 'LOST (ORGANIZATION)': 1, 'Hugest (PERSON)': 1, 'FULLLER (ORGANIZATION)': 1, 'HOLY (ORGANIZATION)': 1, 'Which (PERSON)': 1, 'DRYDEN (ORGANIZATION)': 1, 'THOMAS (ORGANIZATION)': 3, 'HERBERT (ORGANIZATION)': 1, 'INTO (ORGANIZATION)': 1, 'AFRICA (ORGANIZATION)': 1, 'HARRIS (ORGANIZATION)': 2, 'COLL (GPE)': 1, 'SCHOUTEN (ORGANIZATION)': 1, 'Elbe (ORGANIZATION)': 1, 'Jonas (ORGANIZATION)': 1, 'Whale (GPE)': 10, 'Shetland (GPE)': 1, 'Spitzbergen (GPE)': 2, 'VOYAGE TO (ORGANIZATION)': 1, 'GREENLAND (GPE)': 1, 'Pitferren (GPE)': 1, 'SIBBALD (ORGANIZATION)': 1, 'Sperma (GPE)': 1, 'RICHARD (ORGANIZATION)': 1, 'BERMUDAS (ORGANIZATION)': 1, 'PHIL (GSP)': 1, 'COWLEY (ORGANIZATION)': 1, 'GLOBE (ORGANIZATION)': 2, 'ULLOA (ORGANIZATION)': 1, 'AMERICA (ORGANIZATION)': 1, 'Tho (PERSON)': 1, 'THE LOCK (ORGANIZATION)': 1, 'GOLDSMITH (ORGANIZATION)': 1, 'NAT (ORGANIZATION)': 1, 'GOLDSMITH TO JOHNSON (ORGANIZATION)': 1, 'COOK (ORGANIZATION)': 1, 'UNO (ORGANIZATION)': 1, 'SOLANDER (ORGANIZATION)': 1, 'ICELAND (ORGANIZATION)': 1, 'Spermacetti Whale (ORGANIZATION)': 1, 'Nantuckois (ORGANIZATION)': 1, 'JEFFERSON (ORGANIZATION)': 1, 'EDMUND (ORGANIZATION)': 2, 'PARLIAMENT (ORGANIZATION)': 1, 'NANTUCKET (ORGANIZATION)': 7, 'WHALE (ORGANIZATION)': 12, 'FISHERY (ORGANIZATION)': 1, 'Spain (GPE)': 4, 'Europe (GPE)': 4, 'SOMEWHERE (ORGANIZATION)': 1, 'BLACKSTONE (ORGANIZATION)': 1, 'FALCONER (ORGANIZATION)': 1, 'Bright (GPE)': 1, 'Up (GPE)': 3, 'COWPER (ORGANIZATION)': 1, 'QUEEN (ORGANIZATION)': 1, 'JOHN HUNTER (PERSON)': 1, 'DISSECTION OF A (ORGANIZATION)': 1, 'SMALL (ORGANIZATION)': 1, 'London Bridge (ORGANIZATION)': 1, 'PALEY (ORGANIZATION)': 1, 'BARON (ORGANIZATION)': 1, 'Spermacetti Whales (PERSON)': 1, 'COLNETT (ORGANIZATION)': 1, 'PURPOSE OF (ORGANIZATION)': 1, 'SPERMACETI (ORGANIZATION)': 1, 'Floundered (PERSON)': 1, ' ...

# %%
for w in sorted(NE_NLTK_text1, key=NE_NLTK_text1.get, reverse=True):
    print(NE_NLTK_text1[w], "\t", w)
# Out:
# 1 	 (PERSON Amittai/NNP)
# 1 	 (ORGANIZATION Captains/NNP)
# 1 	 (PERSON Cadiz/NNP)
# 1 	 (GPE Cadiz/NNP)
# 1 	 (ORGANIZATION Gibraltar/NNP)
# 1 	 (GPE Miserable/JJ)
# 1 	 (GPE Tarshish/JJ)
# 1 	 (GPE Strong/JJ)
# 1 	 (PERSON Jack/NNP)
# 1 	 (PERSON Joe/NNP)
# 1 	 (GPE Sodom/NNP)
# 1 	 (ORGANIZATION Customs/NNP)
# 1 	 (GPE Tarshish/VB)
# 1 	 (PERSON Captain/NNP)
# 1 	 (GPE Point/NN)
# 1 	 (GPE Wave/NNP)
# 1 	 (GPE Whence/NNP)
# 1 	 (GPE Hebrew/NNP)
# 1 	 (PERSON O/NNP Jonah/NNP)
# 1 	 (ORGANIZATION Lord/NNP God/NNP)
# 1 	 (PERSON Sin/NNP)
# 1 	 (ORGANIZATION Book/NNP)
# 1 	 (ORGANIZATION Joppa/NNP)
# 1 	 (ORGANIZATION Almighty/NNP)
# 1 	 (GPE Falsehood/NN)
# 1 	 (GPE Gospel/NNP)
# 1 	 (PERSON Pilot/NN Paul/NNP)
# 1 	 (ORGANIZATION Senators/NNS)
# 1 	 (GPE Judges/NNP)
# 1 	 (ORGANIZATION Ages/NNP)
# 1 	 (PERSON Thy/NNP)
# 1 	 (PERSON Thine/NNP)
# 1 	 (GPE Thee/NNP)
# 1 	 (GPE Savage/NN)
# 1 	 (ORGANIZATION General/NNP Washington/NNP)
# 1 	 (PERSON George/NNP Washington/NNP)
# 1 	 (ORGANIZATION Socratic/JJ)
# 1 	 (GPE Cape/NNP Horn/NNP)
# 1 	 (ORGANIZATION Tomahawk/NNP)
# 1 	 (ORGANIZATION High/JJ Chief/NNP)
# 1 	 (ORGANIZATION High/JJ Priest/NNP)
# 1 	 (ORGANIZATION Sag/NNP Harbor/NNP)
# 1 	 (GPE Wales/NNP)
# 1 	 (PERSON Czar/NNP Peter/NNP)
# 1 	 (ORGANIZATION Potluck/NNP)
# 1 	 (GPE Moss/NNP)
# 1 	 (GPE Sag/NNP Harbor/NNP)
# 1 	 (ORGANIZATION Rokovoko/NNP)
# 1 	 (PERSON Grace/NNP)
# 1 	 (GPE Priest/NNP)
# 1 	 (ORGANIZATION Acushnet/NNP)
# 1 	 (GPE Huge/NNP)
# 1 	 (PERSON Tartar/NNP)
# 1 	 (ORGANIZATION Moss/NNP)
# 1 	 (GPE Sultan/NNP)
# 1 	 (GPE Capting/NNP)
# 1 	 (GPE Kill/NNP)
# 1 	 (ORGANIZATION Humane/NNP)
# 1 	 (ORGANIZATION Magnanimous/NNP Societies/NNP)
# 1 	 (GPE Nantucket/NN)
# 1 	 (ORGANIZATION Laplander/NNP)
# 1 	 (ORGANIZATION Behring/NNP)
# 1 	 (PERSON Mastodon/NNP)
# 1 	 (GPE Texas/NNP)
# 1 	 (PERSON Cuba/NNP)
# 1 	 (ORGANIZATION Nantucketer/NNP)
# 1 	 (GPE Merchant/NNP)
# 1 	 (ORGANIZATION Noah/NNP)
# 1 	 (PERSON Inn/NNP)
# 1 	 (PERSON Cousin/NNP Hosea/NNP)
# 1 	 (PERSON Tophet/NNP)
# 1 	 (PERSON Cods/NNP)
# 1 	 (PERSON Shirt/NNP)
# 1 	 (GPE Fishiest/NNP)
# 1 	 (GPE Chowder/NN)
# 1 	 (PERSON Hosea/NNP)
# 1 	 (ORGANIZATION ILE/NNP)
# 1 	 (ORGANIZATION Ship/NNP)
# 1 	 (ORGANIZATION XXXIX/NNP Articles/NNP)
# 1 	 (GPE DEVIL/NNP)
# 1 	 (ORGANIZATION DAM/NNP)
# 1 	 (ORGANIZATION TIT/NNP)
# 1 	 (ORGANIZATION BIT/NNP)
# 1 	 (ORGANIZATION PEQUOD/NNP)
# 1 	 (ORGANIZATION Massachusetts/NNP Indians/NNPS)
# 1 	 (GPE Canterbury/NNP)
# 1 	 (PERSON Becket/NNP)
# 1 	 (ORGANIZATION Captain/NNP Peleg/NNP)
# 1 	 (PERSON Thorkill/NNP)
# 1 	 (PERSON Hake/NNP)
# 1 	 (PERSON Sachem/NNP)
# 1 	 (GPE Marchant/NNP)
# 1 	 (PERSON Cape/NNP Cod/NNP)
# 1 	 (GPE Clap/NNP)
# 1 	 (GPE Answer/NNP)
# 1 	 (ORGANIZATION Quakers/NNS)
# 1 	 (ORGANIZATION Scripture/NNP)
# 1 	 (PERSON Pagan/NNP Roman/NNP)
# 1 	 (PERSON Nantucket/NNP Quakerism/NNP)
# 1 	 (ORGANIZATION Categut/NNP)
# 1 	 (GPE Indolence/NN)
# 1 	 (ORGANIZATION Thunder/NNP Cloud/NNP)
# 1 	 (PERSON Ashore/NN)
# 1 	 (PERSON Bildad/NN)
# 1 	 (ORGANIZATION TEENTH/NNP)
# 1 	 (PERSON Thou/NNP Bildad/NNP)
# 1 	 (GPE Blast/NNP)
# 1 	 (GPE Whew/NN)
# 1 	 (GPE Fetch/NNP)
# 1 	 (PERSON Tistig/NNP)
# 1 	 (ORGANIZATION Gayhead/NNP)
# 1 	 (GPE Humiliation/NNP)
# 1 	 (GPE Apoplexy/NN)
# 1 	 (PERSON Hussey/NN)
# 1 	 (PERSON Betty/NNP)
# 1 	 (ORGANIZATION Painter/NNP)
# 1 	 (PERSON Kill/NNP)
# 1 	 (ORGANIZATION Atlantic/NNP Ocean/NNP)
# 1 	 (GPE Ramadan/NN)
# 1 	 (GPE Hygiene/NNP)
# 1 	 (PERSON Son/NN)
# 1 	 (ORGANIZATION Congregational/NNP Church/NNP)
# 1 	 (GPE Deacon/NNP)
# 1 	 (PERSON Coleman/NNP)
# 1 	 (ORGANIZATION First/NNP Congregational/NNP Church/NNP)
# 1 	 (ORGANIZATION Hittite/NNP)
# 1 	 (PERSON First/NNP Congregation/NNP)
# 1 	 (ORGANIZATION SPLICE/NNP)
# 1 	 (PERSON Deacon/NNP)
# 1 	 (PERSON Quick/NNP)
# 1 	 (PERSON Hedgehog/NNP)
# 1 	 (GPE Belial/JJ)
# 1 	 (ORGANIZATION Scriptural/NNP)
# 1 	 (GPE Pious/JJ)
# 1 	 (ORGANIZATION Nat/NNP Swaine/NNP)
# 1 	 (GPE Peleg/NN)
# 1 	 (GPE Have/NNP)
# 1 	 (GPE Ye/NNP)
# 1 	 (PERSON Step/NN)
# 1 	 (GPE Santa/NNP)
# 1 	 (GPE Tistig/NNP)
# 1 	 (ORGANIZATION Peleg/NNP)
# 1 	 (PERSON Aboard/NNP)
# 1 	 (GPE Lookee/NNP)
# 1 	 (PERSON Ain/NNP)
# 1 	 (PERSON Pacific/NNP Oceans/NNP)
# 1 	 (GPE Elijah/NNP)
# 1 	 (PERSON Shan/NNP)
# 1 	 (FACILITY Grand/NNP Jury/NNP)
# 1 	 (PERSON Perry/NNP)
# 1 	 (PERSON Merry/NNP Christmas/NNP)
# 1 	 (PERSON Muster/NNP)
# 1 	 (GPE Booble/NNP Alley/NNP)
# 1 	 (ORGANIZATION Charity/NNP)
# 1 	 (GPE Watts/NNP)
# 1 	 (GPE Quohog/NN)
# 1 	 (GPE Scotch/NNP)
# 1 	 (PERSON Lank/NNP)
# 1 	 (ORGANIZATION Bildad/NNP)
# 1 	 (PERSON Stand/NNP)
# 1 	 (PERSON Canaan/NNP)
# 1 	 (PERSON Jordan/NNP)
# 1 	 (GPE Capes/NNP)
# 1 	 (LOCATION Eastern/NNP Continents/NNP)
# 1 	 (GPE Careful/NNP)
# 1 	 (GPE Luck/NNP)
# 1 	 (ORGANIZATION Lee/NNP Shore/NNP)
# 1 	 (GPE Wonderfullest/NNP)
# 1 	 (GPE Bulkington/NNP)
# 1 	 (GPE Know/NNP)
# 1 	 (PERSON O/NNP Bulkington/NNP)
# 1 	 (ORGANIZATION Advocate/NNP)
# 1 	 (PERSON Sperm/NNP Whale/NNP Fishery/NNP)
# 1 	 (GPE De/NNP Witt/NNP)
# 1 	 (PERSON Louis/NNP XVI/NNP)
# 1 	 (GPE Dunkirk/NNP)
# 1 	 (GPE Britain/NNP)
# 1 	 (GPE L1/NNP)
# 1 	 (PERSON Vancouver/NNP)
# 1 	 (ORGANIZATION Cooks/NNP)
# 1 	 (GPE Krusensterns/NNP)
# 1 	 (GPE Krusenstern/NNP)
# 1 	 (PERSON Cook/NNP)
# 1 	 (LOCATION South/NNP Sea/NNP Voyages/NNP)
# 1 	 (ORGANIZATION Vancouver/NNP)
# 1 	 (ORGANIZATION Old/NNP Spain/NNP)
# 1 	 (GPE Dutchman/NNP)
# 1 	 (GPE Australian/JJ)
# 1 	 (GPE Polynesia/NNP)
# 1 	 (GPE Other/JJ)
# 1 	 (GPE Norwegian/JJ)
# 1 	 (ORGANIZATION Parliament/NNP)
# 1 	 (PERSON Edmund/NNP Burke/NNP)
# 1 	 (ORGANIZATION GOOD/JJ)
# 1 	 (ORGANIZATION BLOOD/NNP)
# 1 	 (PERSON Benjamin/NNP Franklin/NNP)
# 1 	 (PERSON Mary/NNP Morrel/NNP)
# 1 	 (PERSON Mary/NNP Folger/NNP)
# 1 	 (ORGANIZATION Folgers/NNS)
# 1 	 (ORGANIZATION NOT/NNP)
# 1 	 (GPE Whaling/NNP)
# 1 	 (ORGANIZATION DIGNITY/NNP)
# 1 	 (GPE Cetus/NNP)
# 1 	 (ORGANIZATION MSS/NNP)
# 1 	 (ORGANIZATION Yale/JJ College/NNP)
# 1 	 (GPE Certain/NN)
# 1 	 (GPE Outward/NNP)
# 1 	 (PERSON Just/NNP Spirit/NNP)
# 1 	 (GPE Equality/NNP)
# 1 	 (PERSON Bunyan/NNP)
# 1 	 (GPE Cervantes/NNPS)
# 1 	 (PERSON Andrew/NNP Jackson/NNP)
# 1 	 (PERSON O/NNP God/NNP)
# 1 	 (GPE Cod/NNP)
# 1 	 (GPE Long/JJ)
# 1 	 (GPE Tisbury/NNP)
# 1 	 (GPE Martha/NNP)
# 1 	 (GPE Arctic/NNP)
# 1 	 (ORGANIZATION Gothic/NNP Knight/NNP)
# 1 	 (PERSON Next/NNP)
# 1 	 (PERSON Gay/NNP Head/NNP)
# 1 	 (PERSON Vineyard/NNP)
# 1 	 (GPE Gay/NNP)
# 1 	 (PERSON Antarctic/NNP)
# 1 	 (ORGANIZATION Powers/NNS of/IN the/DT Air/NNP)
# 1 	 (GPE Curious/JJ)
# 1 	 (PERSON Ahasuerus/NNP Daggoo/NNP)
# 1 	 (ORGANIZATION Squire/NNP)
# 1 	 (PERSON Herein/NNP)
# 1 	 (ORGANIZATION American/JJ Canals/NNP)
# 1 	 (PERSON Railroads/NNP)
# 1 	 (ORGANIZATION Shetland/NNP Islands/NNP)
# 1 	 (ORGANIZATION Islanders/NNP)
# 1 	 (ORGANIZATION ISOLATOES/NNP)
# 1 	 (ORGANIZATION ISOLATO/NNP)
# 1 	 (PERSON Old/NNP Ahab/NNP)
# 1 	 (ORGANIZATION Little/NNP)
# 1 	 (PERSON Christmas/NNP)
# 1 	 (GPE Reality/NNP)
# 1 	 (PERSON Cellini/NNP)
# 1 	 (PERSON April/NNP)
# 1 	 (PERSON Earls/NNP)
# 1 	 (ORGANIZATION DID/NNP)
# 1 	 (ORGANIZATION Tic/NNP)
# 1 	 (GPE Dolly/NNP)
# 1 	 (ORGANIZATION Pipe/NNP)
# 1 	 (GPE Norse/NNP)
# 1 	 (GPE Leviathans/NNP)
# 1 	 (GPE Slid/JJ)
# 1 	 (PERSON Wise/NNP Stubb/NNP)
# 1 	 (PERSON Halloa/NNP)
# 1 	 (GPE Zoology/NNP)
# 1 	 (PERSON Cetology/NNP)
# 1 	 (PERSON Utter/NNP)
# 1 	 (PERSON Surgeon/NNP Beale/NNP)
# 1 	 (GPE Unfitness/NN)
# 1 	 (PERSON Lesson/NNP)
# 1 	 (GPE Bible/NNP)
# 1 	 (GPE Aristotle/NNP)
# 1 	 (GPE Aldrovandi/NNP)
# 1 	 (PERSON Sir/NNP Thomas/NNP Browne/NNP)
# 1 	 (GPE Gesner/NNP)
# 1 	 (GPE Ray/NNP)
# 1 	 (GPE Linnaeus/NNP)
# 1 	 (GPE Rondeletius/NNP)
# 1 	 (GPE Willoughby/NNP)
# 1 	 (GPE Green/NNP)
# 1 	 (GPE Artedi/NNP)
# 1 	 (GPE Sibbald/NNP)
# 1 	 (GPE Brisson/NNP)
# 1 	 (GPE Marten/NNP)
# 1 	 (GPE Bonneterre/NNP)
# 1 	 (PERSON Baron/NNP Cuvier/NNP)
# 1 	 (GPE Beale/NNP)
# 1 	 (ORGANIZATION Author/NNP)
# 1 	 (PERSON Miriam/NNP Coffin/NNP)
# 1 	 (GPE Olmstead/NNP)
# 1 	 (GPE English/NNP South/NNP)
# 1 	 (GPE Job/NNP)
# 1 	 (PERSON Simeon/NNP Macey/NNP)
# 1 	 (PERSON Charley/NNP Coffin/NNP)
# 1 	 (ORGANIZATION FISH/NN)
# 1 	 (ORGANIZATION HORIZONTAL/NNP)
# 1 	 (GPE Nantucketers/NNP)
# 1 	 (PERSON Lamatins/NNP)
# 1 	 (GPE Dugongs/NNP)
# 1 	 (ORGANIZATION Pig/NNP)
# 1 	 (ORGANIZATION Sow/NNP)
# 1 	 (ORGANIZATION Coffins/NNP)
# 1 	 (ORGANIZATION Kingdom/NNP)
# 1 	 (ORGANIZATION BOOKS/NNP)
# 1 	 (ORGANIZATION CHAPTERS/NNP)
# 1 	 (ORGANIZATION PORPOISE/NNP)
# 1 	 (GPE FOLIOS/NNP)
# 1 	 (ORGANIZATION BACKED/NNP)
# 1 	 (ORGANIZATION BOTTOM/NNP)
# 1 	 (ORGANIZATION Trumpa/NNP)
# 1 	 (ORGANIZATION Physeter/NNP)
# 1 	 (ORGANIZATION Anvil/NNP Headed/NNP)
# 1 	 (ORGANIZATION Pottsfich/NNP)
# 1 	 (ORGANIZATION Macrocephalus/NNP)
# 1 	 (ORGANIZATION Long/NNP Words/NNP)
# 1 	 (ORGANIZATION Black/NNP Whale/NNP)
# 1 	 (ORGANIZATION Great/NNP Whale/NNP)
# 1 	 (ORGANIZATION Great/JJ Mysticetus/NNP)
# 1 	 (ORGANIZATION Baliene/NNP Ordinaire/NNP)
# 1 	 (ORGANIZATION Growlands/NNP Walfish/NNP)
# 1 	 (GPE Swedes/NNP)
# 1 	 (ORGANIZATION Brazil/NNP Banks/NNP)
# 1 	 (LOCATION West/NNP Coast/NNP)
# 1 	 (PERSON Right/NNP Whale/NNP Cruising/NNP Grounds/NNP)
# 1 	 (GPE Fin/NNP)
# 1 	 (GPE Tall/NNP)
# 1 	 (GPE Ahaz/NNP)
# 1 	 (ORGANIZATION WHALEBONE/NNP)
# 1 	 (ORGANIZATION Whalebone/NNP)
# 1 	 (GPE Broad/NNP)
# 1 	 (ORGANIZATION Bibliographical/JJ)
# 1 	 (ORGANIZATION Elephant/NNP)
# 1 	 (GPE Castle/NNP)
# 1 	 (GPE BOTTOM/NNP)
# 1 	 (GPE Tartarian/JJ)
# 1 	 (PERSON Sulphur/NNP Bottom/NNP)
# 1 	 (ORGANIZATION Quarto/NNP)
# 1 	 (ORGANIZATION Octavo/NNP)
# 1 	 (ORGANIZATION Black/NNP Fish/NNP)
# 1 	 (ORGANIZATION Hyena/NNP Whale/NNP)
# 1 	 (GPE Mephistophelean/NNP)
# 1 	 (ORGANIZATION NOSTRIL/NNP)
# 1 	 (PERSON Coffin/NNP)
# 1 	 (GPE Tusked/NNP)
# 1 	 (GPE Horned/NNP)
# 1 	 (ORGANIZATION Unicorn/NNP)
# 1 	 (ORGANIZATION Unicornism/NNP)
# 1 	 (PERSON Letter/NNP)
# 1 	 (PERSON Sir/NNP Martin/NNP Frobisher/NNP)
# 1 	 (PERSON Queen/NNP Bess/NNP)
# 1 	 (GPE Greenwich/NNP Palace/NNP)
# 1 	 (GPE Thames/NNPS)
# 1 	 (PERSON Sir/NNP Martin/NNP)
# 1 	 (PERSON Black/NNP Letter/NNP)
# 1 	 (ORGANIZATION Windsor/NNP)
# 1 	 (GPE Irish/JJ)
# 1 	 (ORGANIZATION Earl/NNP)
# 1 	 (PERSON Leicester/NNP)
# 1 	 (GPE Feegee/NNP)
# 1 	 (ORGANIZATION Killer/NNP)
# 1 	 (GPE Exception/NN)
# 1 	 (PERSON Bonapartes/NNP)
# 1 	 (PERSON Sharks/NNP)
# 1 	 (GPE Killer/NNP)
# 1 	 (GSP DUODECIMOES/NNP)
# 1 	 (ORGANIZATION Algerine/NNP Porpoise/NNP)
# 1 	 (GPE Mealy/NNP)
# 1 	 (ORGANIZATION WHALES/NNP)
# 1 	 (ORGANIZATION HUZZA/NNP)
# 1 	 (PERSON Huzza/NNP Porpoise/NNP)
# 1 	 (ORGANIZATION ALGERINE/NNP)
# 1 	 (ORGANIZATION MEALY/NNP)
# 1 	 (ORGANIZATION MOUTHED/NNP)
# 1 	 (PERSON Whale/NNP Porpoise/NNP)
# 1 	 (GPE Octavo/NNP)
# 1 	 (GPE Duodecimo/NNP)
# 1 	 (ORGANIZATION Bottle/NNP)
# 1 	 (PERSON Nose/NNP Whale/NNP)
# 1 	 (ORGANIZATION Junk/NNP Whale/NNP)
# 1 	 (ORGANIZATION Pudding/NNP)
# 1 	 (ORGANIZATION Cape/NNP Whale/NNP)
# 1 	 (ORGANIZATION Leading/NNP Whale/NNP)
# 1 	 (ORGANIZATION Cannon/NNP Whale/NNP)
# 1 	 (ORGANIZATION Scragg/NNP Whale/NNP)
# 1 	 (ORGANIZATION Coppered/NNP Whale/NNP)
# 1 	 (ORGANIZATION Elephant/NNP Whale/NNP)
# 1 	 (ORGANIZATION Iceberg/NNP Whale/NNP)
# 1 	 (ORGANIZATION Quog/NNP Whale/NNP)
# 1 	 (ORGANIZATION Blue/NNP Whale/NNP)
# 1 	 (GPE Icelandic/NNP)
# 1 	 (GPE Leviathanism/NNP)
# 1 	 (PERSON Cologne/NNP)
# 1 	 (PERSON Time/NNP)
# 1 	 (PERSON Strength/NNP)
# 1 	 (PERSON Cash/NNP)
# 1 	 (PERSON Patience/NN)
# 1 	 (PERSON Dutch/NN Fishery/NNP)
# 1 	 (GPE Cutter/NN)
# 1 	 (PERSON Harpooneer/NNP)
# 1 	 (ORGANIZATION Greenland/NNP Fishery/NNP)
# 1 	 (GPE Specksioneer/NNP)
# 1 	 (ORGANIZATION Harpooneer/NNP)
# 1 	 (ORGANIZATION American/JJ)
# 1 	 (GPE Southern/JJ)
# 1 	 (GPE Mesopotamian/JJ)
# 1 	 (ORGANIZATION Divine/NNP Inert/NNP)
# 1 	 (GPE Nicholas/NNP)
# 1 	 (PERSON Kings/NNP)
# 1 	 (GPE Table/NN)
# 1 	 (FACILITY Grand/NNP Turk/NNP)
# 1 	 (GPE Abjectus/NNP)
# 1 	 (GPE Babylon/NNP)
# 1 	 (PERSON Belshazzar/NNP)
# 1 	 (PERSON Caesar/NNP)
# 1 	 (ORGANIZATION Coronation/NNP)
# 1 	 (ORGANIZATION Frankfort/NNP)
# 1 	 (ORGANIZATION German/JJ Emperor/NNP)
# 1 	 (ORGANIZATION Imperial/NNP Electors/NNPS)
# 1 	 (ORGANIZATION Flask/NNP)
# 1 	 (PERSON Boy/NN)
# 1 	 (GPE Moorish/JJ)
# 1 	 (ORGANIZATION Grisly/NNP Bears/NNP)
# 1 	 (PERSON Spring/NN)
# 1 	 (PERSON Summer/NNP)
# 1 	 (GPE Egyptians/NNPS)
# 1 	 (GPE Babel/NNP)
# 1 	 (ORGANIZATION Africa/NNP)
# 1 	 (GPE Saint/NNP Stylites/NNP)
# 1 	 (GPE Vendome/NNP)
# 1 	 (PERSON Louis/NNP Philippe/NNP)
# 1 	 (PERSON Louis/NNP Blanc/NNP)
# 1 	 (ORGANIZATION Washington/NNP)
# 1 	 (GPE Baltimore/NNP)
# 1 	 (ORGANIZATION Admiral/NNP)
# 1 	 (GPE Trafalgar/NNP Square/NNP)
# 1 	 (PERSON London/NNP)
# 1 	 (PERSON Napoleon/NNP)
# 1 	 (PERSON Obed/NNP Macy/NNP)
# 1 	 (ORGANIZATION Bay/NNP)
# 1 	 (ORGANIZATION NESTS/NN)
# 1 	 (GPE Captain/NNP Sleet/NNP)
# 1 	 (ORGANIZATION Icebergs/NNP)
# 1 	 (ORGANIZATION Lost/NNP Icelandic/NNP Colonies/NNP)
# 1 	 (ORGANIZATION Old/NNP)
# 1 	 (ORGANIZATION SLEET/NNP)
# 1 	 (ORGANIZATION Sleet/NNP)
# 1 	 (ORGANIZATION Phaedon/NNP)
# 1 	 (GPE Bowditch/NNP)
# 1 	 (GPE Childe/NNP)
# 1 	 (PERSON Harold/NNP)
# 1 	 (PERSON Crammer/NNP)
# 1 	 (GPE Descartian/JJ)
# 1 	 (ORGANIZATION Quarter/NNP)
# 1 	 (GPE Deck/NNP)
# 1 	 (ORGANIZATION ENTER/NNP)
# 1 	 (PERSON Twill/NNP)
# 1 	 (GPE Send/NNP)
# 1 	 (GPE Skin/NNP)
# 1 	 (GPE And/CC)
# 1 	 (PERSON Good/NNP Hope/NNP)
# 1 	 (ORGANIZATION Norway/NNP Maelstrom/NNP)
# 1 	 (PERSON Steward/NN)
# 1 	 (GPE Hoot/NN)
# 1 	 (GPE Madness/NN)
# 1 	 (PERSON Hark/NNP)
# 1 	 (GSP Turkish/JJ)
# 1 	 (GPE Round/NN)
# 1 	 (GPE Short/JJ)
# 1 	 (PERSON Satan/NNP)
# 1 	 (PERSON Steward/NNP)
# 1 	 (PERSON Vitus/NNP)
# 1 	 (GPE Advance/NNP)
# 1 	 (GPE Cross/NNP)
# 1 	 (GPE Perchance/NN)
# 1 	 (ORGANIZATION Pope/NNP)
# 1 	 (GPE Forthwith/NNP)
# 1 	 (ORGANIZATION STERN/NNP)
# 1 	 (GPE Dry/NNP)
# 1 	 (ORGANIZATION HIS/NNP HAND/NNP)
# 1 	 (ORGANIZATION WINDOW/NNP)
# 1 	 (PERSON Burkes/NNP)
# 1 	 (PERSON Bendigoes/NNP)
# 1 	 (PERSON Naught/NNP)
# 1 	 (ORGANIZATION MAINMAST/NNP)
# 1 	 (ORGANIZATION BURST/NNP OF/NNP)
# 1 	 (ORGANIZATION FORECASTLE/NNP)
# 1 	 (GPE Fore/NNP)
# 1 	 (ORGANIZATION BRACE/NNP)
# 1 	 (ORGANIZATION WISE/NNP)
# 1 	 (GPE Fa/NNP)
# 1 	 (GPE Midnight/NNP)
# 1 	 (ORGANIZATION Forecastle/NNP)
# 1 	 (ORGANIZATION SAILORS/NNP)
# 1 	 (ORGANIZATION FORESAIL/NNP)
# 1 	 (ORGANIZATION WATCH/NNP)
# 1 	 (ORGANIZATION LOUNGING/NNP)
# 1 	 (ORGANIZATION LEANING/NNP)
# 1 	 (ORGANIZATION ALL/NNP)
# 1 	 (ORGANIZATION THRUSTS/NNP)
# 1 	 (ORGANIZATION Star/NNP)
# 1 	 (PERSON Amsterdam/NNP)
# 1 	 (GPE Blanket/NNP)
# 1 	 (ORGANIZATION SULKY/NNP)
# 1 	 (GPE Beat/NNP)
# 1 	 (GPE Form/NN)
# 1 	 (GPE Legs/NN)
# 1 	 (GPE ICELAND/NNP)
# 1 	 (GPE LONG/NNP)
# 1 	 (ORGANIZATION ISLAND/NNP)
# 1 	 (GPE Hoe/NNP)
# 1 	 (ORGANIZATION ASCENDING/NN)
# 1 	 (ORGANIZATION THE/DT)
# 1 	 (ORGANIZATION HALF/NNP OF/NNP)
# 1 	 (ORGANIZATION COILS/NNP OF/NNP)
# 1 	 (ORGANIZATION PLENTY/NNP)
# 1 	 (ORGANIZATION DANCING/NN)
# 1 	 (GPE Make/NNP)
# 1 	 (GPE CHINA/NNP)
# 1 	 (GPE Rattle/NNP)
# 1 	 (GPE Merry/NNP)
# 1 	 (GPE Split/NNP)
# 1 	 (ORGANIZATION QUIETLY/NNP)
# 1 	 (GPE Dance/NN)
# 1 	 (GPE Spell/NNP)
# 1 	 (ORGANIZATION SKY/NNP)
# 1 	 (ORGANIZATION WIND/NNP)
# 1 	 (ORGANIZATION LASCAR/NNP)
# 1 	 (PERSON Ganges/NNS)
# 1 	 (PERSON Seeva/NNP)
# 1 	 (ORGANIZATION RECLINING/NN AND/CC)
# 1 	 (ORGANIZATION SHAKING/NNP)
# 1 	 (GPE Eh/NNP)
# 1 	 (PERSON Pagan/NNP)
# 1 	 (ORGANIZATION NUDGING/NNP)
# 1 	 (GPE TAHITAN/NNP)
# 1 	 (ORGANIZATION MAT/NNP)
# 1 	 (GPE Hail/NNP)
# 1 	 (ORGANIZATION Heeva/NNP)
# 1 	 (PERSON Heeva/NN)
# 1 	 (PERSON Pirohitee/NNP)
# 1 	 (GPE PORTUGUESE/NNP)
# 1 	 (ORGANIZATION Cattegat/NNP)
# 1 	 (ORGANIZATION ADVANCING/NNP)
# 1 	 (ORGANIZATION GRIMLY/NNP)
# 1 	 (GPE None/NN)
# 1 	 (ORGANIZATION JAGO/NNP)
# 1 	 (PERSON Spaniard/NNP)
# 1 	 (ORGANIZATION SPRINGING/NNP)
# 1 	 (GPE Swallow/NNP)
# 1 	 (GPE SPANISH/JJ)
# 1 	 (ORGANIZATION SAILOR/NNP)
# 1 	 (ORGANIZATION MEETING/NNP)
# 1 	 (PERSON Knife/NNP)
# 1 	 (GPE TASHTEGO/NNP)
# 1 	 (ORGANIZATION BELFAST/NNP)
# 1 	 (GPE Plunge/NN)
# 1 	 (PERSON Cain/NNP)
# 1 	 (PERSON Abel/NNP)
# 1 	 (GPE PIP/NNP)
# 1 	 (ORGANIZATION SHRINKING/NNP)
# 1 	 (ORGANIZATION WINDLASS/NNP)
# 1 	 (GPE Crish/JJ)
# 1 	 (GPE Blang/NNP)
# 1 	 (GPE Duck/NNP)
# 1 	 (GPE Jimmini/NNP)
# 1 	 (GPE Southern/NNP)
# 1 	 (PERSON Olassen/NNP)
# 1 	 (PERSON Povelson/NNP)
# 1 	 (ORGANIZATION Natural/JJ History/NNP)
# 1 	 (GPE Povelson/NNP)
# 1 	 (PERSON Strello/NNP)
# 1 	 (GPE Portugal/NNP)
# 1 	 (ORGANIZATION Arethusa/NNP)
# 1 	 (GPE Syracuse/NNP)
# 1 	 (ORGANIZATION Holy/NNP Land/NNP)
# 1 	 (ORGANIZATION Arkansas/NNP)
# 1 	 (GPE Malay/NNP)
# 1 	 (PERSON Ophites/NNP)
# 1 	 (GPE Moby/NNP Dick/NNP)
# 1 	 (PERSON Patagonian/JJ Cape/NNP)
# 1 	 (GPE Human/NNP)
# 1 	 (ORGANIZATION Northman/NNP)
# 1 	 (PERSON Cluny/NNP)
# 1 	 (GPE Thermes/NNP)
# 1 	 (GPE Caryatid/NNP)
# 1 	 (ORGANIZATION State/NNP)
# 1 	 (GPE Gnawed/NNP)
# 1 	 (ORGANIZATION Whiteness/NNP)
# 1 	 (GPE Pegu/NNP)
# 1 	 (FACILITY White/NNP Elephants/NNPS)
# 1 	 (GPE Siam/NNP)
# 1 	 (GPE Hanoverian/JJ)
# 1 	 (GPE Austrian/JJ Empire/NNP)
# 1 	 (GPE Caesarian/NNP)
# 1 	 (ORGANIZATION Red/NNP Men/NNP)
# 1 	 (ORGANIZATION Justice/NNP)
# 1 	 (PERSON Great/NNP Jove/NNP)
# 1 	 (FACILITY White/NNP Dog/NNP)
# 1 	 (ORGANIZATION Great/NNP Spirit/NNP)
# 1 	 (ORGANIZATION Vision/NNP)
# 1 	 (ORGANIZATION Holy/NNP)
# 1 	 (GPE Romish/JJ)
# 1 	 (PERSON Requiem/NNP)
# 1 	 (ORGANIZATION REQUIEM/NNP)
# 1 	 (ORGANIZATION REQUIN/NNP)
# 1 	 (GPE Wondrous/JJ)
# 1 	 (PERSON Abraham/NNP)
# 1 	 (GPE Goney/NN)
# 1 	 (PERSON Coleridge/NNP)
# 1 	 (PERSON Rhyme/NNP)
# 1 	 (GPE Rhyme/NNP)
# 1 	 (ORGANIZATION Prairies/NNPS)
# 1 	 (ORGANIZATION Rocky/NNP Mountains/NNP)
# 1 	 (GPE Ohio/NNP)
# 1 	 (LOCATION Southern/NNP Seas/NNP)
# 1 	 (FACILITY White/NNP Squall/NNP)
# 1 	 (GPE Froissart/NNP)
# 1 	 (FACILITY White/NNP Hoods/NNP)
# 1 	 (GPE Whitsuntide/NNP)
# 1 	 (ORGANIZATION Protestant/NNP)
# 1 	 (GPE Middle/NNP American/NNP States/NNPS)
# 1 	 (FACILITY White/NNP Friar/NNP)
# 1 	 (FACILITY White/NNP Nun/NNP)
# 1 	 (FACILITY White/NNP Tower/NNP)
# 1 	 (ORGANIZATION Byward/NNP Tower/NNP)
# 1 	 (ORGANIZATION Bloody/NNP)
# 1 	 (FACILITY White/NNP Mountains/NNPS)
# 1 	 (PERSON Blue/NNP Ridge/NNP)
# 1 	 (FACILITY White/NNP Sea/NNP)
# 1 	 (ORGANIZATION Yellow/NNP Sea/NNP)
# 1 	 (ORGANIZATION Central/NNP Europe/NNP)
# 1 	 (ORGANIZATION Hartz/NNP)
# 1 	 (ORGANIZATION Blocksburg/NNP)
# 1 	 (PERSON Pizarro/NNP)
# 1 	 (GPE Vermont/NNP)
# 1 	 (ORGANIZATION Christian/NNP)
# 1 	 (GPE Deity/NNP)
# 1 	 (GPE Lapland/NNP)
# 1 	 (GPE Wonder/NNP)
# 1 	 (GPE Cholo/NNP)
# 1 	 (GPE Pass/NN)
# 1 	 (PERSON Caramba/NN)
# 1 	 (PERSON Grin/NNP)
# 1 	 (GPE Cabaco/NNP)
# 1 	 (ORGANIZATION Lieutenant/NNP Maury/NNP)
# 1 	 (ORGANIZATION National/NNP Observatory/NNP)
# 1 	 (GPE VEINS/NNP)
# 1 	 (ORGANIZATION VEIN/NNP)
# 1 	 (ORGANIZATION Seychelle/NNP)
# 1 	 (PERSON Volcano/NNP Bay/NNP)
# 1 	 (ORGANIZATION Zodiac/NNP)
# 1 	 (ORGANIZATION Bengal/NNP Bay/NNP)
# 1 	 (GPE China/NNP Seas/NNP)
# 1 	 (PERSON Monsoons/NNP)
# 1 	 (GPE Pampas/NNP)
# 1 	 (GPE Harmattans/NNP)
# 1 	 (GPE Trades/NNP)
# 1 	 (ORGANIZATION Levanter/NNP)
# 1 	 (GPE Simoon/NNP)
# 1 	 (PERSON Mufti/NNP)
# 1 	 (ORGANIZATION Affidavit/NNP)
# 1 	 (ORGANIZATION Sperm/NNP Whale/NNP Fishery/NNP)
# 1 	 (PERSON Rinaldo/NNP Rinaldini/NNP)
# 1 	 (ORGANIZATION Cambyses/NNS)
# 1 	 (GPE Caesar/NNP)
# 1 	 (PERSON O/NNP Timor/NNP Tom/NNP)
# 1 	 (GPE Ombay/NNP)
# 1 	 (PERSON O/NNP New/NNP Zealand/NNP Jack/NNP)
# 1 	 (ORGANIZATION Tattoo/NNP Land/NNP)
# 1 	 (PERSON O/NNP Morquan/NNP)
# 1 	 (PERSON O/NNP Don/NNP Miguel/NNP)
# 1 	 (ORGANIZATION Cetacean/NNP History/NNP)
# 1 	 (PERSON Marius/NNP)
# 1 	 (PERSON Sylla/NNP)
# 1 	 (ORGANIZATION Zealand/NNP Tom/NNP)
# 1 	 (PERSON Don/NNP Miguel/NNP)
# 1 	 (ORGANIZATION Narragansett/NNP Woods/NNP)
# 1 	 (PERSON Captain/NNP Butler/NNP)
# 1 	 (PERSON Annawon/NNP)
# 1 	 (PERSON Essex/NNP)
# 1 	 (ORGANIZATION Pacific/NNP Ocean/NNP)
# 1 	 (PERSON Owen/NNP Chace/NNP)
# 1 	 (GPE Again/NN)
# 1 	 (ORGANIZATION HORRID/NNP)
# 1 	 (ORGANIZATION MYSTERIOUS/NNP)
# 1 	 (ORGANIZATION MORTAL/NNP)
# 1 	 (ORGANIZATION ANIMAL/NNP)
# 1 	 (PERSON Union/NNP)
# 1 	 (GPE Oahu/NNP)
# 1 	 (PERSON Sandwich/NNP Islands/NNP)
# 1 	 (ORGANIZATION Valparaiso/NNP)
# 1 	 (PERSON Saul/NNP)
# 1 	 (PERSON Tarsus/NNP)
# 1 	 (PERSON Langsdorff/NNP)
# 1 	 (ORGANIZATION Admiral/NNP Krusenstern/NNP)
# 1 	 (ORGANIZATION Langsdorff/NNP)
# 1 	 (GPE Ochotsh/NNP)
# 1 	 (ORGANIZATION D/NNP)
# 1 	 (FACILITY Captain/NNP D/NNP)
# 1 	 (GPE New/NNP Englander/NNP)
# 1 	 (GPE Siberian/JJ)
# 1 	 (ORGANIZATION Lionel/NNP Wafer/NNP)
# 1 	 (PERSON Dampier/NNP)
# 1 	 (PERSON John/NNP Ferdinando/NNP)
# 1 	 (PERSON Juan/NNP Fernandes/NNP)
# 1 	 (ORGANIZATION Main/NNP)
# 1 	 (GPE Captain/NNP Davis/NNP)
# 1 	 (PERSON Pusie/NNP Hall/NNP)
# 1 	 (PERSON Emperor/NNP)
# 1 	 (ORGANIZATION Belisarius/NNP)
# 1 	 (GPE Procopius/NNP)
# 1 	 (PERSON Marmora/NNP)
# 1 	 (ORGANIZATION Commodore/NNP Davis/NNP)
# 1 	 (GPE Dardanelles/NNP)
# 1 	 (ORGANIZATION BRIT/NNP)
# 1 	 (ORGANIZATION Roman/NNP Emperor/NNP)
# 1 	 (ORGANIZATION Starbuck/NNP)
# 1 	 (ORGANIZATION Mat/NNP)
# 1 	 (GPE Maker/NN)
# 1 	 (ORGANIZATION Loom/NNP)
# 1 	 (GPE Header/NN)
# 1 	 (ORGANIZATION First/NNP Lowering/NNP)
# 1 	 (GPE Less/NNP)
# 1 	 (GPE Manillas/NNP)
# 1 	 (GPE Spread/NNP)
# 1 	 (GPE Tut/NN)
# 1 	 (GPE Easy/NNP)
# 1 	 (GPE Bite/NNP)
# 1 	 (PERSON Starbuck/NN)
# 1 	 (GPE Strong/NNP)
# 1 	 (ORGANIZATION Pull/NNP)
# 1 	 (PERSON Passion/NNP)
# 1 	 (ORGANIZATION Vanity/NNP)
# 1 	 (GPE Seen/NNP)
# 1 	 (GPE Roar/NNP)
# 1 	 (GPE Squall/NNP)
# 1 	 (GPE Wet/NNP)
# 1 	 (GSP Considering/NNP)
# 1 	 (PERSON Boat/NNP)
# 1 	 (ORGANIZATION Crew/NNP)
# 1 	 (PERSON Tamerlane/NNP)
# 1 	 (ORGANIZATION Asiatic/JJ)
# 1 	 (GPE Genesis/NNP)
# 1 	 (PERSON Rabbins/NNP)
# 1 	 (ORGANIZATION Spirit/NNP)
# 1 	 (GPE Plate/NNP)
# 1 	 (ORGANIZATION Carrol/NNP Ground/NNP)
# 1 	 (PERSON Helena/NNP)
# 1 	 (GPE Cape/NN)
# 1 	 (PERSON Cape/NNP Tormentoto/NNP)
# 1 	 (PERSON Right/NNP Whalemen/NNP)
# 1 	 (GPE Goney/NNP)
# 1 	 (GPE Swim/NNP)
# 1 	 (ORGANIZATION Islands/NNP)
# 1 	 (ORGANIZATION Pine/NNP Barrens/NNP)
# 1 	 (GPE New/NNP York/NNP State/NNP)
# 1 	 (ORGANIZATION Salisbury/NNP Plain/NNP)
# 1 	 (PERSON Pine/NNP Barrens/NNP)
# 1 	 (ORGANIZATION Salisbury/NNP Plains/NNP)
# 1 	 (PERSON Mills/NNP)
# 1 	 (ORGANIZATION Yankee/NN)
# 1 	 (ORGANIZATION Nantucketer/NN)
# 1 	 (ORGANIZATION Men/NNP)
# 1 	 (PERSON Pirates/NNP)
# 1 	 (PERSON Man/NNP)
# 1 	 (PERSON War/NNP)
# 1 	 (PERSON Noah/NNP Webster/NNP)
# 1 	 (ORGANIZATION Lexicon/NNP)
# 1 	 (ORGANIZATION SOCIAL/NNP)
# 1 	 (ORGANIZATION OR/NNP)
# 1 	 (ORGANIZATION WHALESHIPS/NNP)
# 1 	 (ORGANIZATION GENERALLY/NNP)
# 1 	 (ORGANIZATION CRUISING/NNP)
# 1 	 (GPE GROUND/NN)
# 1 	 (ORGANIZATION AFTER/NNP)
# 1 	 (ORGANIZATION BOATS/NNP)
# 1 	 (ORGANIZATION CREWS/NNP)
# 1 	 (ORGANIZATION THE/DT TIME/NNP)
# 1 	 (ORGANIZATION ONE/NNP)
# 1 	 (ORGANIZATION TOLD/NNP)
# 1 	 (ORGANIZATION GOLDEN/NNP)
# 1 	 (ORGANIZATION Lima/NNP)
# 1 	 (PERSON Pedro/NNP)
# 1 	 (GPE Sebastian/NNP)
# 1 	 (PERSON Sperm/NNP Whaler/NNP)
# 1 	 (GPE Buffalo/NNP)
# 1 	 (PERSON Lakeman/NN)
# 1 	 (GPE Pray/NN)
# 1 	 (PERSON Lake/NNP Erie/NNP)
# 1 	 (GPE Callao/NN)
# 1 	 (GPE Manilla/NNP)
# 1 	 (PERSON Erie/NNP)
# 1 	 (PERSON Ontario/NNP)
# 1 	 (PERSON Huron/NNP)
# 1 	 (ORGANIZATION Superior/NNP)
# 1 	 (GPE Polynesian/JJ)
# 1 	 (GPE Mackinaw/NNP)
# 1 	 (PERSON Tartar/NNP Emperors/NNP)
# 1 	 (GPE Cleveland/NNP)
# 1 	 (GPE Winnebago/NNP)
# 1 	 (PERSON Borean/NNP)
# 1 	 (PERSON Steelkilt/NNP Charlemagne/NNP)
# 1 	 (PERSON Charlemagne/NNP)
# 1 	 (ORGANIZATION Rad/NNP)
# 1 	 (PERSON Lakeman/NNP)
# 1 	 (GPE Pardon/NNS)
# 1 	 (GPE Venetianly/NNP)
# 1 	 (PERSON Ashantee/NNP)
# 1 	 (PERSON Dame/NNP Isabella/NNP)
# 1 	 (GPE Proceed/NNP)
# 1 	 (GPE Pardon/NN)
# 1 	 (GPE Limeese/JJ)
# 1 	 (GPE Venice/NNP)
# 1 	 (PERSON Dominic/NNP)
# 1 	 (ORGANIZATION Canaller/NNP)
# 1 	 (PERSON Mark/NNP Antony/NNP)
# 1 	 (PERSON Cleopatra/NNP)
# 1 	 (GPE Canallers/NNP)
# 1 	 (GPE Sydney/NNP)
# 1 	 (FACILITY Grand/NNP Canal/NNP)
# 1 	 (PERSON Water/NNP)
# 1 	 (ORGANIZATION Steelkilt/NNP)
# 1 	 (GPE Shipmate/NNP)
# 1 	 (GPE Rad/NNP)
# 1 	 (GPE Twenty/NNP)
# 1 	 (GPE Jesu/NNP)
# 1 	 (ORGANIZATION Dick/NNP)
# 1 	 (PERSON Dominic/NN)
# 1 	 (GPE Whom/NNP)
# 1 	 (PERSON Dons/NNP)
# 1 	 (GSP Dons/NNP)
# 1 	 (PERSON Sirs/NNP)
# 1 	 (ORGANIZATION Teneriffe/NNP)
# 1 	 (GPE Gentlemen/NNP)
# 1 	 (ORGANIZATION Radney/NNP)
# 1 	 (PERSON Ho/NN)
# 1 	 (PERSON Senor/NNP)
# 1 	 (ORGANIZATION Tahiti/NNP)
# 1 	 (GSP Don/NNP)
# 1 	 (PERSON Sebastian/NNP)
# 1 	 (ORGANIZATION Holy/NNP Evangelists/NNPS)
# 1 	 (GPE Auto/NNP)
# 1 	 (PERSON Fe/NNP)
# 1 	 (ORGANIZATION Holy/NNP Book/NNP)
# 1 	 (ORGANIZATION Monstrous/NNP Pictures/NNPS)
# 1 	 (PERSON Hindoo/NN)
# 1 	 (PERSON Saladin/NNP)
# 1 	 (ORGANIZATION Brahmins/NNP)
# 1 	 (ORGANIZATION Hindoo/NNP)
# 1 	 (GPE Vishnu/NNP)
# 1 	 (ORGANIZATION Matse/NNP Avatar/NNP)
# 1 	 (PERSON Hogarth/NNP)
# 1 	 (PERSON Perseus/NNP Descending/NNP)
# 1 	 (GPE Hogarthian/JJ)
# 1 	 (ORGANIZATION Traitors/NNP)
# 1 	 (PERSON Scotch/NNP Sibbald/NNP)
# 1 	 (ORGANIZATION Revival/NNP)
# 1 	 (GPE Learning/NNP)
# 1 	 (PERSON Saratoga/NNP)
# 1 	 (PERSON Jonas/NNP)
# 1 	 (PERSON Peter/NNP Peterson/NNP)
# 1 	 (ORGANIZATION Post/NNP Captain/NNP)
# 1 	 (ORGANIZATION Spermaceti/NNP Whale/NNP Fisheries/NNP)
# 1 	 (ORGANIZATION Goldsmith/NNP)
# 1 	 (PERSON Animated/NNP Nature/NNP)
# 1 	 (PERSON Bernard/NNP Germain/NNP)
# 1 	 (PERSON Count/NNP)
# 1 	 (PERSON Lacepede/NNP)
# 1 	 (ORGANIZATION Mysticetus/NNP)
# 1 	 (PERSON Baron/NNP)
# 1 	 (PERSON Richard/NNP III/NNP)
# 1 	 (PERSON Jeremy/NNP Bentham/NNP)
# 1 	 (PERSON Jeremy/NNP)
# 1 	 (ORGANIZATION Less/NNP Erroneous/NNP Pictures/NNP)
# 1 	 (ORGANIZATION True/NNP Pictures/NNP)
# 1 	 (PERSON Purchas/NNP)
# 1 	 (GPE Harris/NNP)
# 1 	 (GPE J/NNP)
# 1 	 (GPE Serious/JJ)
# 1 	 (GPE Patagonian/JJ)
# 1 	 (GPE Versailles/NNP)
# 1 	 (LOCATION Northern/NNP Lights/NNP)
# 1 	 (ORGANIZATION American/NNP)
# 1 	 (ORGANIZATION Leuwenhoeck/NNP)
# 1 	 (GPE Durand/NNP)
# 1 	 (GPE Paint/NNP)
# 1 	 (GPE Teeth/NNP)
# 1 	 (GPE Sheet/NNP)
# 1 	 (GPE Iron/NN)
# 1 	 (GPE Stone/NNP)
# 1 	 (GPE Mountains/NNP)
# 1 	 (GPE Stars/NNP)
# 1 	 (GPE Tower/NNP)
# 1 	 (ORGANIZATION KEDGER/NNP)
# 1 	 (GPE Wapping/NNP)
# 1 	 (PERSON Sag/NNP Harbor/NNP)
# 1 	 (GPE Cannibals/NNP)
# 1 	 (GPE Hawaiian/NNP)
# 1 	 (GPE Hawaiian/JJ)
# 1 	 (PERSON Achilles/NNP)
# 1 	 (PERSON Albert/NNP Durer/NNP)
# 1 	 (GPE Wooden/NNP)
# 1 	 (ORGANIZATION HANDS/NNP)
# 1 	 (ORGANIZATION Soloma/NNP Islands/NNP)
# 1 	 (PERSON Mendanna/NNP)
# 1 	 (PERSON Figuera/NNP)
# 1 	 (ORGANIZATION Eastern/JJ)
# 1 	 (ORGANIZATION Argo/NNP)
# 1 	 (PERSON Navis/NN)
# 1 	 (PERSON Cetus/NNP)
# 1 	 (GPE Hydrus/NNP)
# 1 	 (GPE Fish/NNP)
# 1 	 (GPE Brit/NNP)
# 1 	 (GPE Right/JJ)
# 1 	 (ORGANIZATION Brazil/NNP Banks/NNPS)
# 1 	 (ORGANIZATION Banks/NNP)
# 1 	 (GPE Wherein/NNP)
# 1 	 (GPE Hebrews/NNP)
# 1 	 (GPE Korah/NNP)
# 1 	 (PERSON Push/NNP)
# 1 	 (GPE Bare/NNP)
# 1 	 (ORGANIZATION Kraken/NNP)
# 1 	 (PERSON Bishop/NNP Pontoppodan/NNP)
# 1 	 (GPE Squid/NNP)
# 1 	 (ORGANIZATION Bishop/NNP)
# 1 	 (ORGANIZATION Anak/NNP)
# 1 	 (GPE Hemp/NNP)
# 1 	 (PERSON Manilla/NNP)
# 1 	 (GPE Circassian/JJ)
# 1 	 (GPE Calais/NNP)
# 1 	 (PERSON Edward/NNP)
# 1 	 (PERSON Squid/NNP)
# 1 	 (PERSON Plata/NNP)
# 1 	 (PERSON Peru/NNP)
# 1 	 (GPE Luff/NN)
# 1 	 (ORGANIZATION Ontario/NNP Indians/NNPS)
# 1 	 (ORGANIZATION Woo/NNP)
# 1 	 (GPE Wa/NNP)
# 1 	 (GPE Ka/NNP)
# 1 	 (GPE Koo/NNP)
# 1 	 (GPE Grenadier/NNP)
# 1 	 (GPE Whole/JJ)
# 1 	 (ORGANIZATION Atlantics/NNPS)
# 1 	 (PERSON Pacifics/NNPS)
# 1 	 (ORGANIZATION Dart/NNP)
# 1 	 (GPE Crotch/NNP)
# 1 	 (GPE Hang/NNP)
# 1 	 (PERSON Darkness/NNP)
# 1 	 (PERSON Ebony/NNP)
# 1 	 (GPE Fellow/NNP)
# 1 	 (PERSON Massa/NNP)
# 1 	 (GPE Den/NNP)
# 1 	 (GPE Belubed/NNP)
# 1 	 (PERSON Massa/NNP Stubb/NNP)
# 1 	 (GPE Kick/NNP)
# 1 	 (PERSON Hind/NNP)
# 1 	 (GPE Main/NNP)
# 1 	 (GPE Wish/JJ)
# 1 	 (PERSON Massa/NNP Shark/NNP)
# 1 	 (GPE Dish/NNP)
# 1 	 (PERSON Henry/NNP VIIIth/NNP)
# 1 	 (GPE Porpoises/NNS)
# 1 	 (GPE Dunfermline/NNP)
# 1 	 (GSP Zogranda/NNP)
# 1 	 (ORGANIZATION Amsterdam/NNP)
# 1 	 (PERSON Brute/NN)
# 1 	 (ORGANIZATION Society/NNP)
# 1 	 (GPE Cruelty/NNP)
# 1 	 (ORGANIZATION Ganders/NNP)
# 1 	 (PERSON Shark/NNP Massacre/NNP)
# 1 	 (LOCATION Southern/JJ Fishery/NNP)
# 1 	 (PERSON Ingin/NNP)
# 1 	 (GPE Sabbath/NNP)
# 1 	 (GPE Whereupon/NNP)
# 1 	 (ORGANIZATION Blanket/NNP)
# 1 	 (LOCATION Upper/NNP Mississippi/NNP)
# 1 	 (ORGANIZATION Agassiz/NNP)
# 1 	 (GPE Borneo/NNP)
# 1 	 (ORGANIZATION Funeral/NNP)
# 1 	 (ORGANIZATION ROCKS/NNP)
# 1 	 (ORGANIZATION BREAKERS/NNP)
# 1 	 (ORGANIZATION Cock/NNP)
# 1 	 (PERSON Doctor/NNP Johnson/NNP)
# 1 	 (GPE Sphynx/NNP)
# 1 	 (ORGANIZATION Stubb/NNP)
# 1 	 (ORGANIZATION Holofernes/NNP)
# 1 	 (GPE Judith/NNP)
# 1 	 (ORGANIZATION Sphynx/NNP)
# 1 	 (ORGANIZATION American/NNP Whale/NNP Fleet/NNP)
# 1 	 (PERSON Mayhew/NNP)
# 1 	 (GPE Subject/JJ)
# 1 	 (GPE Jeroboam/NNP)
# 1 	 (PERSON Neskyeuna/NNP Shakers/NNP)
# 1 	 (PERSON Neskyeuna/NNP)
# 1 	 (GPE Captain/NNP Mayhew/NNP)
# 1 	 (ORGANIZATION Shaker/NNP God/NNP)
# 1 	 (ORGANIZATION Shakers/NNPS)
# 1 	 (PERSON Whale/JJ Fishery/NNP)
# 1 	 (GPE Macey/NNP)
# 1 	 (GPE Straightway/NNP)
# 1 	 (PERSON Har/NNP)
# 1 	 (PERSON Harry/NNP Macey/NNP)
# 1 	 (PERSON Ship/NNP Jeroboam/NNP)
# 1 	 (ORGANIZATION Mayhew/NNP)
# 1 	 (GPE Monkey/NNP)
# 1 	 (GPE Rope/NN)
# 1 	 (GPE Providence/NNP)
# 1 	 (GPE Yojo/NNP)
# 1 	 (ORGANIZATION Temperance/NNP Society/NNP)
# 1 	 (PERSON Flask/NNP Kill/NNP)
# 1 	 (ORGANIZATION Crozetts/NNP)
# 1 	 (GPE Cut/NNP)
# 1 	 (PERSON Bargain/NN)
# 1 	 (ORGANIZATION Asiatic/NNP)
# 1 	 (PERSON Doesn/NNP)
# 1 	 (GPE Locke/NNP)
# 1 	 (GPE Kant/NNP)
# 1 	 (GPE Laplandish/JJ)
# 1 	 (ORGANIZATION Right/NNP)
# 1 	 (PERSON Far/NNP)
# 1 	 (GPE Euclid/NNP)
# 1 	 (PERSON Herschel/NNP)
# 1 	 (PERSON Kentucky/NNP Mammoth/NNP Cave/NNP)
# 1 	 (ORGANIZATION Greenlanders/NNPS)
# 1 	 (LOCATION Southern/JJ)
# 1 	 (ORGANIZATION Mackinaw/NNP)
# 1 	 (GPE Purchas/NNP)
# 1 	 (ORGANIZATION CHOP/NNP)
# 1 	 (GPE Queen/NNP Anne/NNP)
# 1 	 (GPE Turkey/NN)
# 1 	 (GPE Stoic/NNP)
# 1 	 (GPE Platonian/JJ)
# 1 	 (ORGANIZATION Spinoza/NNP)
# 1 	 (ORGANIZATION Battering/NNP)
# 1 	 (GPE Ram/NN)
# 1 	 (GPE Indiamen/NNP)
# 1 	 (ORGANIZATION Isthmus/NNP)
# 1 	 (GPE Darien/NNP)
# 1 	 (ORGANIZATION Lais/NNP)
# 1 	 (ORGANIZATION Great/NNP Heidelburgh/NNP Tun/NNP)
# 1 	 (GPE Euclidean/JJ)
# 1 	 (GPE Rhenish/NNP)
# 1 	 (GPE Cistern/NNP)
# 1 	 (GPE Buckets/NNP)
# 1 	 (GPE Nimble/JJ)
# 1 	 (PERSON Niagara/NNP)
# 1 	 (PERSON Table/NNP)
# 1 	 (GPE Rock/NN)
# 1 	 (GPE Drawn/NNP)
# 1 	 (GPE Midwifery/NN)
# 1 	 (ORGANIZATION Prairie/NNP)
# 1 	 (ORGANIZATION Phrenologist/NN)
# 1 	 (ORGANIZATION Rock/NNP)
# 1 	 (GPE Gibraltar/NNP)
# 1 	 (ORGANIZATION Gall/NNP)
# 1 	 (ORGANIZATION Pantheon/NNP)
# 1 	 (PERSON Gall/NNP)
# 1 	 (PERSON Spurzheim/NNP)
# 1 	 (PERSON Phidias/NNP)
# 1 	 (PERSON Shakespeare/NNP)
# 1 	 (PERSON Melancthon/NNP)
# 1 	 (ORGANIZATION Deity/NNP)
# 1 	 (GPE Genius/NNP)
# 1 	 (ORGANIZATION Egypt/NNP)
# 1 	 (GPE Physiognomy/NNP)
# 1 	 (PERSON Sir/NNP William/NNP Jones/NNP)
# 1 	 (ORGANIZATION Nut/NNP)
# 1 	 (GPE Sphinx/NNP)
# 1 	 (GPE Quebec/NNP)
# 1 	 (ORGANIZATION Pequod/NNP Meets/NNPS The/DT Virgin/NNP)
# 1 	 (PERSON Derick/NNP De/NNP Deer/NNP)
# 1 	 (GPE Yarman/NNP)
# 1 	 (ORGANIZATION Yarman/NNP)
# 1 	 (GPE Newcastle/NNP)
# 1 	 (PERSON Captain/NNP Derick/NNP De/NNP Deer/NNP)
# 1 	 (GPE Full/NN)
# 1 	 (GPE Adverse/JJ)
# 1 	 (GPE Hindostan/NNP)
# 1 	 (GPE Dog/NN)
# 1 	 (GPE Are/NNP)
# 1 	 (GPE Halloo/NNP)
# 1 	 (ORGANIZATION DON/NNP)
# 1 	 (PERSON Yarman/NNP)
# 1 	 (ORGANIZATION Yarman/NN)
# 1 	 (PERSON Bernard/NNP)
# 1 	 (PERSON Xerxes/NNP)
# 1 	 (LOCATION West/NNP Indian/NNP)
# 1 	 (GPE Hold/NN)
# 1 	 (ORGANIZATION Shore/NNP Whaling/NNP)
# 1 	 (ORGANIZATION Bays/NNP)
# 1 	 (PERSON Back/NNP)
# 1 	 (GPE Backs/NNS)
# 1 	 (ORGANIZATION Dericks/NNP)
# 1 	 (ORGANIZATION Honour/NNP)
# 1 	 (GPE Andromeda/NNP)
# 1 	 (PERSON Jaffa/NNP)
# 1 	 (ORGANIZATION Romans/NNPS)
# 1 	 (GPE Italy/NNP)
# 1 	 (GPE Akin/NNP)
# 1 	 (GPE Dragon/NNP)
# 1 	 (PERSON Ezekiel/NNP)
# 1 	 (PERSON Dagon/NNP)
# 1 	 (GPE Israel/NNP)
# 1 	 (PERSON Kit/NNP Carson/NNP)
# 1 	 (GPE Hindoos/NNP)
# 1 	 (GPE Vedas/NNP)
# 1 	 (PERSON Jonah/NNP Historically/NNP Regarded/NNP)
# 1 	 (GPE Romans/NNPS)
# 1 	 (PERSON Arion/NNP)
# 1 	 (ORGANIZATION Hebrew/NNP)
# 1 	 (PERSON Bishop/NNP Jebb/NNP)
# 1 	 (GPE Bishop/NNP)
# 1 	 (GPE Harbor/NN)
# 1 	 (ORGANIZATION DEAD/NNP)
# 1 	 (GPE Russian/NNP)
# 1 	 (PERSON Shark/NNP)
# 1 	 (PERSON Poor/NNP Sag/NNP)
# 1 	 (LOCATION Mediterranean/NNP Sea/NNP)
# 1 	 (ORGANIZATION Red/NNP Sea/NNP)
# 1 	 (PERSON Bartholomew/NNP Diaz/NNP)
# 1 	 (PERSON Turks/NNP)
# 1 	 (PERSON Mosque/NNP)
# 1 	 (PERSON Jungfrau/NNP)
# 1 	 (ORGANIZATION Cleopatra/NNP)
# 1 	 (GPE Actium/NNP)
# 1 	 (PERSON Steel/NNP)
# 1 	 (GPE Fountain/NNP)
# 1 	 (ORGANIZATION SPOUTINGS/NNP)
# 1 	 (GPE Remark/NNP)
# 1 	 (GPE Pyrrho/NNP)
# 1 	 (GPE Devil/NNP)
# 1 	 (PERSON Dante/NNP)
# 1 	 (GPE Tail/NNP)
# 1 	 (GPE Could/NNP)
# 1 	 (GPE Real/JJ)
# 1 	 (PERSON Eckerman/NNP)
# 1 	 (GPE Goethe/NNP)
# 1 	 (PERSON Angelo/NNP)
# 1 	 (ORGANIZATION Son/NNP)
# 1 	 (GPE Third/NNP)
# 1 	 (GPE Fifth/NNP)
# 1 	 (GPE Scroll/NNP)
# 1 	 (ORGANIZATION Darmonodes/NNP)
# 1 	 (GPE Fourth/NN)
# 1 	 (GPE Dantean/NNP)
# 1 	 (GPE Isaiah/NNP)
# 1 	 (GPE Persia/NNP)
# 1 	 (PERSON Ptolemy/NNP Philopater/NNP)
# 1 	 (GPE African/NNP)
# 1 	 (GPE Free/NNP)
# 1 	 (GPE Mason/NNP)
# 1 	 (FACILITY Grand/NNP Armada/NNP)
# 1 	 (GPE Birmah/NNP)
# 1 	 (PERSON Bally/NNP)
# 1 	 (GPE Timor/NNP)
# 1 	 (ORGANIZATION Sunda/NNP)
# 1 	 (PERSON Sumatra/NNP)
# 1 	 (ORGANIZATION Danes/NNPS)
# 1 	 (ORGANIZATION Philippine/NNP Islands/NNP)
# 1 	 (GPE Broad/NN)
# 1 	 (ORGANIZATION Cockatoo/NNP Point/NNP)
# 1 	 (ORGANIZATION Sumatra/NNP)
# 1 	 (PERSON Porus/NNP)
# 1 	 (PERSON Alexander/NNP)
# 1 	 (GPE Witness/NNP)
# 1 	 (GPE Best/NNP)
# 1 	 (ORGANIZATION Commodore/NN)
# 1 	 (ORGANIZATION Nantucket/NNP Indians/NNPS)
# 1 	 (GPE Gulfweed/NNP)
# 1 	 (GPE Line/NN)
# 1 	 (PERSON Madame/NNP Leviathan/NNP)
# 1 	 (PERSON Jacob/NNP)
# 1 	 (ORGANIZATION HOMINUM/NNP)
# 1 	 (ORGANIZATION Arnold/NNP)
# 1 	 (GPE Saratoga/NNP)
# 1 	 (GPE Riotous/JJ)
# 1 	 (ORGANIZATION Schoolmasters/NNP)
# 1 	 (PERSON Ottoman/NNP)
# 1 	 (ORGANIZATION EMBONPOINT/NNP)
# 1 	 (GPE Ottoman/NNP)
# 1 	 (GPE Vidocq/NNP)
# 1 	 (PERSON Daniel/NNP Boone/NNP)
# 1 	 (ORGANIZATION Yale/NNP)
# 1 	 (ORGANIZATION Chinese/JJ Society/NNP)
# 1 	 (PERSON Anne/NNP)
# 1 	 (ORGANIZATION Coke/NNP)
# 1 	 (PERSON Littleton/NN)
# 1 	 (GPE Loose/JJ)
# 1 	 (ORGANIZATION Law/NNP)
# 1 	 (PERSON Possession/NNP)
# 1 	 (ORGANIZATION Republican/JJ)
# 1 	 (GPE Mordecai/NNP)
# 1 	 (PERSON Woebegone/NNP)
# 1 	 (ORGANIZATION Archbishop/NNP)
# 1 	 (GPE L100/NNP)
# 1 	 (PERSON Dunder/NNP)
# 1 	 (PERSON John/NNP Bull/NNP)
# 1 	 (GPE Ireland/NNP)
# 1 	 (PERSON Brother/NNP Jonathan/NNP)
# 1 	 (PERSON Texas/NNP)
# 1 	 (ORGANIZATION Liberties/NNP)
# 1 	 (GPE Tails/NNP)
# 1 	 (GPE De/NNP)
# 1 	 (GPE BRACTON/NNP)
# 1 	 (GPE Latin/NN)
# 1 	 (ORGANIZATION Laws/NNP)
# 1 	 (PERSON Honourary/NNP Grand/NNP Harpooneer/NNP)
# 1 	 (GPE Dover/NNP)
# 1 	 (GPE Sandwich/NNP)
# 1 	 (ORGANIZATION Cinque/NNP Port/NNP)
# 1 	 (PERSON Won/NNP)
# 1 	 (PERSON Wellington/NNP)
# 1 	 (GPE Gold/NN)
# 1 	 (PERSON Bench/NNP)
# 1 	 (PERSON William/NNP Prynne/NNP)
# 1 	 (PERSON Prynne/NNP)
# 1 	 (ORGANIZATION Pequod/NNP Meets/NNPS The/DT Rose/NNP)
# 1 	 (GPE Bud/NNP)
# 1 	 (GPE Ambergriese/NNP)
# 1 	 (GPE V/NNP)
# 1 	 (GPE Assyrian/JJ)
# 1 	 (GPE Frenchmen/NNP)
# 1 	 (ORGANIZATION Rose/NNP)
# 1 	 (ORGANIZATION BOUTON/NNP)
# 1 	 (ORGANIZATION ROSE/NNP)
# 1 	 (ORGANIZATION WHITE/NNP)
# 1 	 (PERSON Cachalot/NNP)
# 1 	 (ORGANIZATION Blanche/NNP)
# 1 	 (FACILITY White/NNP)
# 1 	 (ORGANIZATION YOURS/NNP)
# 1 	 (GPE Fine/NNP)
# 1 	 (PERSON Air/NNP)
# 1 	 (ORGANIZATION Guernseyman/NNP)
# 1 	 (GPE French/NNP)
# 1 	 (PERSON Jago/NNP)
# 1 	 (GPE Bordeaux/NNP)
# 1 	 (PERSON Whereupon/NNP)
# 1 	 (PERSON Captain/NNP Coffin/NNP)
# 1 	 (FACILITY English/NNP House/NNP)
# 1 	 (ORGANIZATION Commons/NNPS)
# 1 	 (GPE Mecca/NNP)
# 1 	 (PERSON Brandreth/NNP)
# 1 	 (GPE Corinthians/NNP)
# 1 	 (ORGANIZATION Paracelsus/NNP)
# 1 	 (LOCATION Southern/NNP)
# 1 	 (GPE Lying/NNP)
# 1 	 (ORGANIZATION Hospital/NN)
# 1 	 (PERSON Schmerenburgh/NNP)
# 1 	 (GPE Smeerenberg/NNP)
# 1 	 (PERSON Fogo/NNP Von/NNP Slack/NNP)
# 1 	 (PERSON Smells/NNP)
# 1 	 (PERSON Whaler/NNP)
# 1 	 (ORGANIZATION Pip/NNP)
# 1 	 (GPE Julys/NNP)
# 1 	 (GPE New/NNP Year/NNP)
# 1 	 (GSP Connecticut/NNP)
# 1 	 (GPE Never/NNP)
# 1 	 (ORGANIZATION STICK/NNP)
# 1 	 (ORGANIZATION LEAP/NNP)
# 1 	 (PERSON Hereby/NNP)
# 1 	 (GPE Wisdom/NNP)
# 1 	 (ORGANIZATION Paracelsan/NNP)
# 1 	 (GPE Squeeze/NN)
# 1 	 (ORGANIZATION Berkshire/NNP)
# 1 	 (GPE Plum/NNP)
# 1 	 (PERSON Louis/NNP)
# 1 	 (PERSON Gros/NNP)
# 1 	 (PERSON Gurry/NNP)
# 1 	 (PERSON Edgewise/NNP)
# 1 	 (GPE Cassock/NNP)
# 1 	 (PERSON Queen/NNP Maachah/NNP)
# 1 	 (GPE Judea/NNP)
# 1 	 (PERSON Kedron/NNP)
# 1 	 (ORGANIZATION First/NNP Book/NNP)
# 1 	 (GPE Kings/NNP)
# 1 	 (GPE Arrayed/NNP)
# 1 	 (GPE Canaris/NNP)
# 1 	 (ORGANIZATION Tartarean/NNP)
# 1 	 (GPE Wrapped/NNP)
# 1 	 (PERSON Uppermost/NN)
# 1 	 (PERSON Dismal/NNP Swamp/NNP)
# 1 	 (PERSON Rome/NNP)
# 1 	 (GPE Campagna/NNP)
# 1 	 (GPE Sahara/NNP)
# 1 	 (GPE Sorrows/NNP)
# 1 	 (GPE Ecclesiastes/NNP)
# 1 	 (PERSON Cowper/NNP)
# 1 	 (PERSON Young/NNP)
# 1 	 (GPE Pascal/NNP)
# 1 	 (GPE Rousseau/NNP)
# 1 	 (PERSON Rabelais/NNP)
# 1 	 (ORGANIZATION Catskill/NNP)
# 1 	 (ORGANIZATION Lamp/NNP)
# 1 	 (PERSON Aladdin/NNP)
# 1 	 (PERSON Down/NNP)
# 1 	 (PERSON Shadrach/NNP)
# 1 	 (PERSON Meshach/NNP)
# 1 	 (GPE Abednego/NNP)
# 1 	 (ORGANIZATION EX/NNP)
# 1 	 (GPE Holland/NN)
# 1 	 (ORGANIZATION Doubloon/NNP)
# 1 	 (PERSON Milky/NNP Way/NNP)
# 1 	 (GPE South/NNP America/NNP)
# 1 	 (GPE Spanishly/JJ)
# 1 	 (ORGANIZATION REPUBLICA/NNP)
# 1 	 (ORGANIZATION Libra/NNP)
# 1 	 (PERSON Lucifer/NNP)
# 1 	 (ORGANIZATION Aries/NNS)
# 1 	 (ORGANIZATION Trinity/NNP)
# 1 	 (ORGANIZATION Righteousness/NNP)
# 1 	 (PERSON Negro/NNP Hill/NNP)
# 1 	 (GPE Corlaer/NNP)
# 1 	 (PERSON Hook/NNP)
# 1 	 (GPE Popayan/NNP)
# 1 	 (ORGANIZATION Golconda/NNP)
# 1 	 (ORGANIZATION Epitome/NNP)
# 1 	 (GPE Hem/NNP)
# 1 	 (GPE Ram/NNP)
# 1 	 (PERSON Jimimi/NNP)
# 1 	 (ORGANIZATION Twins/NNPS)
# 1 	 (GPE Book/NN)
# 1 	 (PERSON Bowditch/NNP)
# 1 	 (GPE Pity/NN)
# 1 	 (GPE Doubloon/NNP)
# 1 	 (PERSON Almanack/NNP)
# 1 	 (PERSON Gemini/NNP)
# 1 	 (GPE Vice/NNP)
# 1 	 (ORGANIZATION Crab/NNP)
# 1 	 (PERSON Leo/NNP)
# 1 	 (PERSON Virgo/NNP)
# 1 	 (ORGANIZATION Virgin/NN)
# 1 	 (PERSON Libra/NNP)
# 1 	 (ORGANIZATION Scales/NNPS)
# 1 	 (PERSON Scorpio/NNP)
# 1 	 (ORGANIZATION Scorpion/NNP)
# 1 	 (GPE Sagittarius/NNP)
# 1 	 (GPE Capricornus/NNP)
# 1 	 (GPE Goat/NNP)
# 1 	 (ORGANIZATION Water/NNP)
# 1 	 (PERSON Pisces/NNS)
# 1 	 (GPE Fishes/NNP)
# 1 	 (PERSON Doubloon/NNP)
# 1 	 (GPE Post/NN)
# 1 	 (GPE Prick/NNP)
# 1 	 (GPE Copenhagen/NNP)
# 1 	 (GPE Cannibal/NNP)
# 1 	 (PERSON Surgeon/NNP)
# 1 	 (PERSON Murray/NNP)
# 1 	 (GPE Caw/NN)
# 1 	 (GPE Hish/JJ)
# 1 	 (GPE Jenny/NN)
# 1 	 (ORGANIZATION Arm/NNP)
# 1 	 (GPE Trumpet/NN)
# 1 	 (GPE Jump/NNP)
# 1 	 (GPE Mounttop/NNP)
# 1 	 (PERSON Bunger/NN)
# 1 	 (PERSON Jack/NNP Bunger/NNP)
# 1 	 (GPE Bunger/NNP)
# 1 	 (PERSON Divine/NNP Providence/NNP)
# 1 	 (GPE Ceylon/NNP)
# 1 	 (FACILITY White/NNP Whales/NNP)
# 1 	 (ORGANIZATION Enderby/NNP)
# 1 	 (GPE Sons/NNP)
# 1 	 (ORGANIZATION Tudors/NNPS)
# 1 	 (GPE Bourbons/NNP)
# 1 	 (PERSON Coffins/NNP)
# 1 	 (ORGANIZATION Maceys/NNP)
# 1 	 (GPE South/NNP Atlantic/NNP)
# 1 	 (ORGANIZATION Nantucketers/NNPS)
# 1 	 (PERSON Samuel/NN)
# 1 	 (PERSON Syren/NNP)
# 1 	 (ORGANIZATION Syren/NNP)
# 1 	 (PERSON Saxon/NNP)
# 1 	 (GPE Flip/NNP)
# 1 	 (ORGANIZATION Hollanders/NNP)
# 1 	 (ORGANIZATION Zealanders/NNP)
# 1 	 (PERSON Danes/NNS)
# 1 	 (PERSON Fitz/NNP Swackhammer/NNP)
# 1 	 (ORGANIZATION High/JJ German/NNP)
# 1 	 (PERSON Santa/NNP Claus/NNP)
# 1 	 (PERSON Pott/NNP)
# 1 	 (GPE Cooper/NNP)
# 1 	 (ORGANIZATION Merchant/NN)
# 1 	 (GPE Texel/NNP)
# 1 	 (GPE Geneva/NNP)
# 1 	 (PERSON Texel/NNP)
# 1 	 (ORGANIZATION Low/NNP Dutch/NNPS)
# 1 	 (GPE Hitherto/NNP)
# 1 	 (GPE Cetacea/NNP)
# 1 	 (GPE Algiers/NNP)
# 1 	 (GPE Bamboo/NNP)
# 1 	 (ORGANIZATION Pupella/NNP)
# 1 	 (PERSON Damocles/NNP)
# 1 	 (ORGANIZATION Icy/NNP Glen/NNP)
# 1 	 (PERSON Dar/NNP)
# 1 	 (PERSON River/NNP Whale/NNP)
# 1 	 (GPE Yorkshire/NNP)
# 1 	 (PERSON Burton/NNP Constable/NNP)
# 1 	 (PERSON Sir/NNP Clifford/NNP Constable/NNP)
# 1 	 (PERSON Sir/NNP Clifford/NNP)
# 1 	 (GPE Skeleton/NNP)
# 1 	 (GPE Feet/NNP)
# 1 	 (PERSON Pompey/NNP)
# 1 	 (PERSON Pillar/NNP)
# 1 	 (ORGANIZATION Fossil/NNP Whale/NNP)
# 1 	 (GPE Applied/NNP)
# 1 	 (GPE Fain/NNP)
# 1 	 (PERSON Vesuvius/NNP)
# 1 	 (PERSON Fossil/NNP Whales/NNP)
# 1 	 (GPE Ark/NNP)
# 1 	 (ORGANIZATION Fossil/NNP Whales/NNP)
# 1 	 (GPE Cetacean/NNP)
# 1 	 (PERSON Detached/NNP)
# 1 	 (ORGANIZATION Alps/NNP)
# 1 	 (GPE Scotland/NNP)
# 1 	 (GPE Louisiana/NNP)
# 1 	 (GPE Mississippi/NNP)
# 1 	 (ORGANIZATION Rue/NNP Dauphine/NNP)
# 1 	 (GPE Paris/NNP)
# 1 	 (GPE Antwerp/NNP)
# 1 	 (PERSON Creagh/NNP)
# 1 	 (GPE Basilosaurus/NNP)
# 1 	 (ORGANIZATION English/NNP Anatomist/NNP)
# 1 	 (PERSON Zeuglodon/NNP)
# 1 	 (ORGANIZATION London/NNP Geological/NNP Society/NNP)
# 1 	 (PERSON Saturn/NNP)
# 1 	 (ORGANIZATION Tropics/NNPS)
# 1 	 (ORGANIZATION Pharaoh/NNP)
# 1 	 (ORGANIZATION Methuselah/NNP)
# 1 	 (ORGANIZATION Shem/NNP)
# 1 	 (GPE Denderah/NNP)
# 1 	 (ORGANIZATION Rafters/NNPS)
# 1 	 (PERSON Beams/NNP)
# 1 	 (GPE Bones/NNS)
# 1 	 (ORGANIZATION Common/NNP People/NNP)
# 1 	 (ORGANIZATION Matter/NNP)
# 1 	 (GPE Temple/NNP)
# 1 	 (PERSON Miles/NNP)
# 1 	 (GPE Miracle/NNP)
# 1 	 (GPE Camel/NNP)
# 1 	 (GPE Mahomet/NNP)
# 1 	 (ORGANIZATION Prophet/NNP Jonas/NNP)
# 1 	 (ORGANIZATION Base/NNP)
# 1 	 (PERSON Afric/NNP Temple/NNP)
# 1 	 (PERSON Magnitude/NNP Diminish/NNP)
# 1 	 (ORGANIZATION Eternities/NNPS)
# 1 	 (ORGANIZATION Aldrovandus/NNP)
# 1 	 (PERSON Rope/NNP Walks/NNP)
# 1 	 (PERSON Thames/NNP Tunnels/NNP)
# 1 	 (GPE Solander/NNP)
# 1 	 (PERSON Cooke/NNP)
# 1 	 (ORGANIZATION Academy/NNP of/IN Sciences/NNPS)
# 1 	 (ORGANIZATION Iceland/NNP Whales/NNP)
# 1 	 (ORGANIZATION Wrinkled/NNP Bellies/NNPS)
# 1 	 (ORGANIZATION Right/JJ Whale/NNP)
# 1 	 (GPE Smithfield/NNP)
# 1 	 (PERSON Pharaoh/NNP)
# 1 	 (PERSON Missouri/NNP)
# 1 	 (GPE Canadian/JJ)
# 1 	 (GPE Swiss/NNP)
# 1 	 (PERSON Harto/NNP)
# 1 	 (GPE Goa/NNP)
# 1 	 (PERSON Siam/NNP)
# 1 	 (PERSON Semiramis/NNP)
# 1 	 (GPE Porus/NNP)
# 1 	 (PERSON Hannibal/NNP)
# 1 	 (GPE Americas/NNP)
# 1 	 (GPE New/NNP Holland/NNP)
# 1 	 (ORGANIZATION Isles/NNP)
# 1 	 (GPE Wherefore/NNP)
# 1 	 (ORGANIZATION Tuileries/NNP)
# 1 	 (ORGANIZATION Windsor/NNP Castle/NNP)
# 1 	 (FACILITY Kremlin/NNP)
# 1 	 (PERSON Ark/NNP)
# 1 	 (GPE Netherlands/NNP)
# 1 	 (GPE Yea/NN)
# 1 	 (GPE Joy/NNP)
# 1 	 (GPE Lama/NNP)
# 1 	 (GPE Saturn/NNP)
# 1 	 (ORGANIZATION MULTUM/NNP)
# 1 	 (ORGANIZATION Sheffield/NNP)
# 1 	 (GPE BENCH/NNP)
# 1 	 (ORGANIZATION LIGHT/NNP OF/NNP)
# 1 	 (ORGANIZATION LANTERNS/NNP)
# 1 	 (ORGANIZATION IVORY/NNP)
# 1 	 (ORGANIZATION LEG/NNP)
# 1 	 (ORGANIZATION SLABS/NNP)
# 1 	 (ORGANIZATION LEATHER/NNP)
# 1 	 (ORGANIZATION PADS/NNP)
# 1 	 (ORGANIZATION SCREWS/NNP)
# 1 	 (ORGANIZATION THE/NNP BENCH/NNP)
# 1 	 (ORGANIZATION FORWARD/NNP)
# 1 	 (ORGANIZATION RED/NNP)
# 1 	 (ORGANIZATION FORGE/NNP)
# 1 	 (ORGANIZATION BLACKSMITH/NNP)
# 1 	 (ORGANIZATION WORK/NNP)
# 1 	 (ORGANIZATION ENSUING/NNP)
# 1 	 (ORGANIZATION CONTINUES/NNP)
# 1 	 (ORGANIZATION Prometheus/NNP)
# 1 	 (GPE Imprimis/NNP)
# 1 	 (ORGANIZATION Thames/NNP Tunnel/NNP)
# 1 	 (GPE Bone/NN)
# 1 	 (GPE Canst/NNP)
# 1 	 (GPE Hah/NN)
# 1 	 (GPE Bungle/NNP)
# 1 	 (ORGANIZATION TURNS/NNP)
# 1 	 (ORGANIZATION RESUMING/NNP)
# 1 	 (ORGANIZATION Formosa/NNP)
# 1 	 (ORGANIZATION Bashee/NNP Isles/NNP)
# 1 	 (PERSON Niphon/NNP)
# 1 	 (PERSON Matsmai/NNP)
# 1 	 (GPE Sikoke/NNP)
# 1 	 (ORGANIZATION Burtons/NNP)
# 1 	 (ORGANIZATION Typhoons/NNP)
# 1 	 (GPE Burton/NNP)
# 1 	 (ORGANIZATION Burtons/NNPS)
# 1 	 (GPE Captain/NNP Noah/NNP)
# 1 	 (GPE Tierce/NN)
# 1 	 (GPE Top/JJ)
# 1 	 (ORGANIZATION Typhoons/NNPS)
# 1 	 (PERSON Zoroaster/NNP)
# 1 	 (PERSON Chaldee/NNP)
# 1 	 (ORGANIZATION Long/NNP Island/NNP)
# 1 	 (GPE Rarmai/NNP)
# 1 	 (PERSON Antilles/NNP)
# 1 	 (GPE Rig/NNP)
# 1 	 (PERSON Hark/NN)
# 1 	 (PERSON Rig/NNP)
# 1 	 (GPE Shame/NN)
# 1 	 (GPE Ephesian/JJ)
# 1 	 (ORGANIZATION Evangelist/NNP St/NNP)
# 1 	 (ORGANIZATION Potters/NNP)
# 1 	 (GPE Magian/JJ)
# 1 	 (GPE Californian/JJ)
# 1 	 (GPE Asiatic/NNP)
# 1 	 (GPE Pan/NNP)
# 1 	 (PERSON Pan/NNP)
# 1 	 (GPE Japanese/NNPS)
# 1 	 (ORGANIZATION Delta/NNP)
# 1 	 (ORGANIZATION Blacksmith/NNP)
# 1 	 (GPE Silent/NNP)
# 1 	 (GPE Belated/VBN)
# 1 	 (ORGANIZATION Bottle/NNP Conjuror/NNP)
# 1 	 (PERSON Labor/NNP)
# 1 	 (GPE Hadst/NNP)
# 1 	 (GPE Untried/NNP)
# 1 	 (ORGANIZATION Wild/NNP)
# 1 	 (GPE Watery/NNP)
# 1 	 (GPE Unshored/NNP)
# 1 	 (ORGANIZATION THY/NNP)
# 1 	 (PERSON Aye/NNP)
# 1 	 (PERSON Carey/NNP)
# 1 	 (GPE Answer/NN)
# 1 	 (PERSON Horse/NNP)
# 1 	 (PERSON Pray/NNP God/NNP)
# 1 	 (ORGANIZATION Icy/NNP Sea/NNP)
# 1 	 (GPE Ahoy/NNP)
# 1 	 (ORGANIZATION Three/NNP Fates/NNP)
# 1 	 (ORGANIZATION Gilder/NNP)
# 1 	 (PERSON Ifs/NNP)
# 1 	 (ORGANIZATION Loveliness/NNP)
# 1 	 (ORGANIZATION Pequod/NNP Meets/NNPS The/DT Bachelor/NNP)
# 1 	 (ORGANIZATION POKE/NNP)
# 1 	 (ORGANIZATION Polynesian/JJ Isles/NNP)
# 1 	 (GPE Long/NNP Island/NNP)
# 1 	 (GPE Bastille/NNP)
# 1 	 (GPE Sail/NN)
# 1 	 (GPE Bachelor/NNP)
# 1 	 (GPE Soothed/NNP)
# 1 	 (ORGANIZATION Niger/NNP)
# 1 	 (ORGANIZATION Whale/NNP Watch/NNP)
# 1 	 (ORGANIZATION Asphaltites/NNP)
# 1 	 (GPE Gomorrah/NNP)
# 1 	 (ORGANIZATION Immortal/NNP)
# 1 	 (ORGANIZATION Quadrant/NNP)
# 1 	 (GPE Foolish/JJ)
# 1 	 (ORGANIZATION Commodores/NNP)
# 1 	 (GPE Captains/NNP)
# 1 	 (GPE Science/NN)
# 1 	 (GPE Level/NN)
# 1 	 (PERSON Parsee/NNP)
# 1 	 (GPE Candles/NNP)
# 1 	 (GPE Warmest/NNP)
# 1 	 (GPE Bengal/NNP)
# 1 	 (GPE Thunder/NN)
# 1 	 (PERSON Avast/NNP)
# 1 	 (PERSON Madman/NN)
# 1 	 (PERSON Tekel/NNP Upharsin/NNP)
# 1 	 (PERSON Satanic/NNP)
# 1 	 (GPE Herculaneum/NNP)
# 1 	 (ORGANIZATION SUDDEN/NNP)
# 1 	 (ORGANIZATION REPEATED/NNP)
# 1 	 (ORGANIZATION NINE/NNP)
# 1 	 (ORGANIZATION REST/NNP)
# 1 	 (ORGANIZATION CLOSES/NNP)
# 1 	 (ORGANIZATION HARD/NNP)
# 1 	 (GPE Light/NNP)
# 1 	 (GPE Leap/NN)
# 1 	 (ORGANIZATION Perth/NNP)
# 1 	 (ORGANIZATION Deck/NNP)
# 1 	 (ORGANIZATION First/NNP Night/NNP Watch/NNP)
# 1 	 (ORGANIZATION THE/NNP HELM/NNP)
# 1 	 (GPE Loftiest/JJS)
# 1 	 (ORGANIZATION Forecastle/NNP Bulwarks/NNP)
# 1 	 (ORGANIZATION ANCHORS/NNP)
# 1 	 (ORGANIZATION ARE/NNP)
# 1 	 (ORGANIZATION Marine/NNP)
# 1 	 (GPE Same/NN)
# 1 	 (ORGANIZATION MAIN/NNP)
# 1 	 (ORGANIZATION TOP/NNP)
# 1 	 (ORGANIZATION SAIL/NNP)
# 1 	 (GPE Plenty/NNP)
# 1 	 (ORGANIZATION Musket/NNP)
# 1 	 (GPE Typhoon/NNP)
# 1 	 (ORGANIZATION FAIR/NNP)
# 1 	 (GPE OH/NNP)
# 1 	 (ORGANIZATION YE/SYM)
# 1 	 (GPE HO/NNP)
# 1 	 (ORGANIZATION CHEERLY/NNP)
# 1 	 (GPE Strange/NNP)
# 1 	 (GPE Flat/JJ)
# 1 	 (PERSON Ahabs/NNP)
# 1 	 (GPE Needle/NNP)
# 1 	 (GPE Babylonian/JJ)
# 1 	 (GPE Yoke/NN)
# 1 	 (PERSON East/NNP)
# 1 	 (GPE Accessory/NNP)
# 1 	 (GPE Abashed/NNP)
# 1 	 (ORGANIZATION Log/NNP)
# 1 	 (PERSON Line/NNP)
# 1 	 (ORGANIZATION Manxman/NNP)
# 1 	 (GPE College/NNP)
# 1 	 (GPE Snap/NN)
# 1 	 (GPE Tahitian/NNP)
# 1 	 (GPE Astern/NNP)
# 1 	 (PERSON Ye/NN)
# 1 	 (GPE Buoy/NNP)
# 1 	 (PERSON Herod/NNP)
# 1 	 (GPE Lord/NN)
# 1 	 (GPE Nail/NNP)
# 1 	 (GPE Hem/NN)
# 1 	 (PERSON Turk/NNP)
# 1 	 (ORGANIZATION COFFIN/NNP)
# 1 	 (ORGANIZATION LINE/NNP)
# 1 	 (ORGANIZATION TUBS/NN)
# 1 	 (ORGANIZATION BETWEEN/NNP)
# 1 	 (ORGANIZATION BENCH/NNP)
# 1 	 (ORGANIZATION OPEN/NNP)
# 1 	 (ORGANIZATION BOSOM/NNP)
# 1 	 (ORGANIZATION GANGWAY/NNP)
# 1 	 (GPE Middle/JJ)
# 1 	 (GPE Titans/NNPS)
# 1 	 (GPE Faith/NNP)
# 1 	 (GPE Despatch/NN)
# 1 	 (PERSON Albemarle/NNP)
# 1 	 (ORGANIZATION Gallipagos/NNP)
# 1 	 (GPE Equator/NNP)
# 1 	 (ORGANIZATION AHAB/UH)
# 1 	 (GPE Blind/NNP)
# 1 	 (GPE Rat/NNP)
# 1 	 (ORGANIZATION Pequod/NNP Meets/NNPS The/DT Rachel/NNP)
# 1 	 (ORGANIZATION Rachel/NNP)
# 1 	 (ORGANIZATION CATCHES/NNP)
# 1 	 (ORGANIZATION HAND/NNP)
# 1 	 (GPE Lad/NNP)
# 1 	 (ORGANIZATION STEP/NNP)
# 1 	 (PERSON Pass/NNP)
# 1 	 (PERSON Monsieurs/NNP)
# 1 	 (ORGANIZATION Parsee/NNP Ahab/NNP)
# 1 	 (GPE Sicilian/JJ)
# 1 	 (PERSON Tanaquil/NNP)
# 1 	 (ORGANIZATION Pequod/NNP Meets/NNPS The/DT Delight/NNP)
# 1 	 (ORGANIZATION Delight/NNP)
# 1 	 (PERSON Hast/NNP)
# 1 	 (GPE Nantucketer/NNP)
# 1 	 (PERSON Brace/NNP)
# 1 	 (ORGANIZATION Symphony/NNP)
# 1 	 (PERSON Samson/NNP)
# 1 	 (GPE Hither/NNP)
# 1 	 (PERSON Invisible/JJ)
# 1 	 (PERSON Miriam/NNP)
# 1 	 (GPE Guinea/NNP)
# 1 	 (GPE Behold/NNP)
# 1 	 (GPE Wife/NNP)
# 1 	 (GPE Sleep/NN)
# 1 	 (ORGANIZATION Mate/NNP)
# 1 	 (GPE Luff/NNP)
# 1 	 (GPE Turkish/NNP)
# 1 	 (GPE Europa/NNP)
# 1 	 (GPE Crete/NNP)
# 1 	 (ORGANIZATION Natural/NNP Bridge/NNP)
# 1 	 (ORGANIZATION Channel/NNP)
# 1 	 (PERSON Antiochus/NNP)
# 1 	 (ORGANIZATION Maccabees/NNP)
# 1 	 (GPE Moby/NNP)
# 1 	 (GPE Man/NN)
# 1 	 (GPE Groan/NNP)
# 1 	 (GPE Cold/NNP)
# 1 	 (GPE Caught/NNP)
# 1 	 (GPE Accursed/JJ)
# 1 	 (ORGANIZATION Parsee/NN)
# 1 	 (GPE Gone/NN)
# 1 	 (PERSON Quick/JJ)
# 1 	 (GPE Jesus/NNP)
# 1 	 (PERSON Impiety/NNP)
# 1 	 (GPE Twas/NNP)
# 1 	 (GPE Believe/NNP)
# 1 	 (PERSON How/NNP)
# 1 	 (GPE Vesuvius/NNP)
# 1 	 (PERSON Trade/NNP Winds/NNP)
# 1 	 (PERSON Leeward/NN)
# 1 	 (PERSON O/NNP Parsee/NNP)
# 1 	 (GPE Future/JJ)
# 1 	 (GPE Strangest/NNP)
# 1 	 (GPE Feel/NNP)
# 1 	 (GPE Crushed/NNP)
# 1 	 (GPE Pull/NN)
# 1 	 (PERSON Monadnock/NNP)
# 1 	 (GPE Burst/NNP)
# 1 	 (GPE Slope/NN)
# 1 	 (GPE Dash/NNP)
# 1 	 (PERSON O/NNP Ahab/NNP)
# 1 	 (GPE Retribution/NN)
# 1 	 (GPE Pole/NNP)
# 1 	 (GPE Sink/NNP)
# 1 	 (ORGANIZATION Fata/NNP Morgana/NNP)
# 1 	 (GPE Satan/NNP)
# 1 	 (GPE Epilogue/NNP)
# 1 	 (ORGANIZATION ONLY/NNP)
# 1 	 (ORGANIZATION TELL/NNP)
# 1 	 (ORGANIZATION Fates/NNS)
# 1 	 (GPE Round/NNP)
# 1 	 (GPE Till/NNP)

# %% [markdown]
# # Named entity recognition with spacy

# %%
# !python3 -m spacy download en_core_web_lg -t .
#import en_core_web_sm

#nlp = en_core_web_sm.load()
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/dist-packages/copkmeans-1.5-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 10.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import spacy
from spacy.lang.en.examples import sentences 
from spacy import displacy

nlp_spacy = spacy.load("en_core_web_lg")

# %%
# pre-process by converting each sentence into a tokenized string
preprocessText(Michelle, 2)

# %%
# create a doc object per sentence
doc_spacy = nlp_spacy(Michelle)

print("Sentence:", doc_spacy.text, "\n\nSpacy Analysis:")
for token in doc_spacy:
    print(f"\t{token.text}\t{token.pos_}\t{token.dep_}")
    
print(f"Entities\n")
for ent in doc_spacy.ents:
    print(f"\t{ent.text:<15}\t{ent.start_char}\t{ent.end_char}\t{ent.label_}")

# %%
# load data
sentence = "Apple is looking at buying U.K. startup for $1 billion"
doc_spacy2 = nlp_spacy(sentence)

# print entities
for ent in doc_spacy2.ents:
    print(f"\t{ent.text:<15}\t{ent.start_char}\t{ent.end_char}\t{ent.label_}")

# %%
# entire Michelle text
doc_spacy3 = nlp_spacy(Michelle)

# collect NES in dictionary
NEs = {}
for ent in doc_spacy3.ents:
    NEs.setdefault(ent.label_, {})
    NEs[ent.label_].setdefault(ent.text, 0)
    NEs[ent.label_][ent.text] += 1

for typ in NEs:
    for txt in NEs[typ]:
        print(f'\t{NEs[typ][txt]}\t{typ:<10}\t{txt}')

# %%
# task:
# preprare text1, with preprocessText(text1, 2)
# loop throgh the list of sentences
# create a doc object per sentence
# grep out the entities 
# count entities and plot by order of frequency

# %% [markdown]
# # Named entity recognition with stanza

# %%
import stanza

nlp_stanza = stanza.Pipeline(lang='en', processors='tokenize,ner')

# %%
doc_stanza1 = nlp_stanza(preprocessText(Michelle, 2)[1])

print(*[f'entity: {ent.text}\ttype: {ent.type}' for ent in doc_stanza1.ents], sep='\n')

for i, sentence in enumerate(doc_stanza1.sentences):
    print(f'====== Sentence {i+1} tokens =======')
    print(*[f'id: {token.id}\ttext: {token.text}' for token in sentence.tokens], sep='\n')

# %%
# takes VERY much time

# list of sentences
text1string = preprocessText(' '.join(text1), 2)


H = {}
for s in text1string[:50]:
    doc_stanza2 = nlp_stanza(s)
    for ent in doc_stanza2.ents:
        H.setdefault(str(ent.type), {})
        H[str(ent.type)].setdefault(str(ent.text), 0)
        H[str(ent.type)][str(ent.text)] += 1

for typ in H:
    for txt in H[typ].keys():
        print(f'\t{H[typ][txt]}\t{typ}\t{txt}')
